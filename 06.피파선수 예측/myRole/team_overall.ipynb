# %%
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# ### 사이트가 막혀있어서 html주석 복사해서 읽음

# %%
html1 = '''

<!DOCTYPE html>
<html lang="ko-KR">
<head id="head">
<title>팀 FIFA 23 2023. 8. 24. SoFIFA</title>
<meta charset="utf-8">
<meta name="viewport" content="width=device-width, initial-scale=1">
<meta name="google-site-verification" content="VGaFvm9Qm-qhCd2LCDi8QKWXNPSrVE2SJ2iT8c3vI1g">
<meta name="description" content="2023. 8. 24. FIFA 23 팀 평점">
<meta name="copyright" content="2009 - 2023 SoFIFA.com">
<meta name="twitter:widgets:theme" content="dark">
<meta name="twitter:widgets:border-color" content="#777777">
<link rel="shortcut icon" href="https://static.sofifa.net/launcher-icon.png">
<link rel="apple-touch-icon" href="https://static.sofifa.net/launcher-icon.png">
<link rel="preconnect" href="https://cdn.intergient.com/" crossorigin>
<link rel="dns-prefetch" href="https://cdn.intergient.com/">
<script>window.ramp = window.ramp || {};window.ramp.que = window.ramp.que || [];</script>
<link rel="alternate" hreflang="en" href="https://sofifa.com/teams?hl=en-US">
<link rel="alternate" hreflang="fr" href="https://sofifa.com/teams?hl=fr-FR">
<link rel="alternate" hreflang="de" href="https://sofifa.com/teams?hl=de-DE">
<link rel="alternate" hreflang="es" href="https://sofifa.com/teams?hl=es-ES">
<link rel="alternate" hreflang="it" href="https://sofifa.com/teams?hl=it-IT">
<link rel="alternate" hreflang="pt-BR" href="https://sofifa.com/teams?hl=pt-BR">
<link rel="alternate" hreflang="nl" href="https://sofifa.com/teams?hl=nl-NL">
<link rel="alternate" hreflang="ko" href="https://sofifa.com/teams?hl=ko-KR">
<link rel="alternate" hreflang="pl" href="https://sofifa.com/teams?hl=pl-PL">
<link rel="alternate" hreflang="zh-CN" href="https://sofifa.com/teams?hl=zh-CN">
<link rel="alternate" hreflang="ru" href="https://sofifa.com/teams?hl=ru-RU">
<link rel="alternate" hreflang="ja" href="https://sofifa.com/teams?hl=ja-JP">
<link rel="alternate" hreflang="sv" href="https://sofifa.com/teams?hl=sv-SE">
<link rel="alternate" hreflang="da" href="https://sofifa.com/teams?hl=da-DK">
<link rel="alternate" hreflang="pt-PT" href="https://sofifa.com/teams?hl=pt-PT">
<link rel="alternate" hreflang="nn" href="https://sofifa.com/teams?hl=nn-NO">
<link rel="alternate" hreflang="hu" href="https://sofifa.com/teams?hl=hu-HU">
<link rel="alternate" hreflang="cs" href="https://sofifa.com/teams?hl=cs-CZ">
<link rel="alternate" hreflang="fi" href="https://sofifa.com/teams?hl=fi-FI">
<link rel="alternate" hreflang="uk" href="https://sofifa.com/teams?hl=uk-UA">
<link rel="alternate" hreflang="tr" href="https://sofifa.com/teams?hl=tr-TR">
<link rel="alternate" hreflang="zh-HK" href="https://sofifa.com/teams?hl=zh-HK">
<link rel="alternate" hreflang="ar" href="https://sofifa.com/teams?hl=ar-AA"><link rel="canonical" href="https://sofifa.com/teams"><link rel="stylesheet" href="https://static.sofifa.net/css/desktop.min.css?39">
<script>let CDN='https://cdn.sofifa.net',CDN_VERSION='20210431',HL='ko-KR',THEME='dark',GENDER=0,IS_MOBILE=false,USER_ID=0,USER_AVATAR='https://cdn.sofifa.net/avatar?name=Guest',BLOCK='블록',UNBLOCK='차단해제',FOLLOW='따르다',UNFOLLOW='팔로우해제',CHOOSE_FILE='파일을선택...',UPLOADING='업로드중...',CHANGE='변화',UPDATED='업데이트',DELETE_CONFIRM='이항목을제거하시겠습니까?',CANCEL='취소',OK='OK',CLOSE='닫기',BLOCK_CONFIRM='이사용자를차단하시겠습니까?<br>나중에\"내관계\"섹션에서설정을변경할수있습니다.',HISTORY_VERSION='역사버전',VERSION='23', ROSTER='230052',FONT=14,LOAD_MORE_COMMENTS='Load more comments',ADD_A_COMMENT='Add a comment',SORT_BY_NEWEST='Sort by newest',SORT_BY_BEST='Sort by best',MY_COMMENTS='My comments',POST='Post',JUST_NOW='just now',COLLAPSE_REPLIES='Collapse replies',COPY_URL='Copy URL',REPORT='신고',UPVOTE='Upvote',DOWNVOTE='Downvote',EDIT='Edit',REPLY='Reply',APPROVE='Approve',REMOVE='없애다',SHOW_FULL_COMMENT='Show full comment',LOAD_IMAGE='Load image',CANCEL_REPLY='Cancel reply',REPLY_TO_THIS_COMMENT='Reply to this comment',CANCEL_EDIT='Cancel edit',EDIT_THIS_COMMENT='Edit this comment',EXPAND_REPLIES='Expand replies',PLEASE_CHOOSE_A_REASON='Please choose a reason',RACISM='Racism',INSULT='Insult',SPAMMING='Spamming',PORN='Porn',PRIVATE_INFO='Private info',OTHER='기타',DESCRIPTION_OPTIONAL='Description (optional)',SAVING='Saving ...',OPERATION_SUCCEED='작업성공',TYPE_TO_SEARCH='검색할유형',AI_MODERATION=1;</script>
</head>
<body class="is-preload  dark" data-class="is-preload  dark" lang="ko-KR" id="body">
<header>
<nav class="bp3-navbar">
<div class="center">
<div class="bp3-navbar-group bp3-align-left reset">
<div class="bp3-navbar-heading">
<a href="/" rel="nofollow"><img alt="SoFIFA" src="https://cdn.sofifa.net/images/launcher-icon.png" width="30" height="30"></a>
</div>
<a href="/players" class="bp3-button bp3-minimal">선수</a>
<a href="/teams" class="bp3-button bp3-minimal">팀</a>
<a href="/squads" class="bp3-button bp3-minimal">분대</a>
<a href="/shortlists" class="bp3-button bp3-minimal">명단</a>
<a rel="nofollow" href="/discussion/1" class="bp3-button bp3-minimal">토론</a>
</div>
<div class="bp3-navbar-group bp3-align-right">
<a rel="nofollow" href="/signIn" role="button" class="bp3-button bp3-minimal need-sign-in" tabindex="101">로그인</a>
<div class="dropdown dropdown-right">
<a rel="nofollow" href="javascript:void(0);" role="button" class="bp3-button bp3-minimal block dropdown-toggle" tabindex="102" title="설정"><span class="bp3-icon"><svg viewBox="0 0 24 24" width="18" height="18"><circle cx="12" cy="12" r="3"></circle><path d="M19.4 15a1.65 1.65 0 0 0 .33 1.82l.06.06a2 2 0 0 1 0 2.83 2 2 0 0 1-2.83 0l-.06-.06a1.65 1.65 0 0 0-1.82-.33 1.65 1.65 0 0 0-1 1.51V21a2 2 0 0 1-2 2 2 2 0 0 1-2-2v-.09A1.65 1.65 0 0 0 9 19.4a1.65 1.65 0 0 0-1.82.33l-.06.06a2 2 0 0 1-2.83 0 2 2 0 0 1 0-2.83l.06-.06a1.65 1.65 0 0 0 .33-1.82 1.65 1.65 0 0 0-1.51-1H3a2 2 0 0 1-2-2 2 2 0 0 1 2-2h.09A1.65 1.65 0 0 0 4.6 9a1.65 1.65 0 0 0-.33-1.82l-.06-.06a2 2 0 0 1 0-2.83 2 2 0 0 1 2.83 0l.06.06a1.65 1.65 0 0 0 1.82.33H9a1.65 1.65 0 0 0 1-1.51V3a2 2 0 0 1 2-2 2 2 0 0 1 2 2v.09a1.65 1.65 0 0 0 1 1.51 1.65 1.65 0 0 0 1.82-.33l.06-.06a2 2 0 0 1 2.83 0 2 2 0 0 1 0 2.83l-.06.06a1.65 1.65 0 0 0-.33 1.82V9a1.65 1.65 0 0 0 1.51 1H21a2 2 0 0 1 2 2 2 2 0 0 1-2 2h-.09a1.65 1.65 0 0 0-1.51 1z"></path></svg></span></a>
<div class="bp3-menu">
<div class="bp3-menu-header">성별</div>
<a class="bp3-menu-item bp3-active" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&gender=0">Men</a>
<a class="bp3-menu-item" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&gender=1">Women</a>
<div class="bp3-menu-header">단위</div>
<a class="bp3-menu-item" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&units=imperial">피트인치/파운드</a>
<a class="bp3-menu-item bp3-active" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&units=mks">cm / kg</a>
<div class="bp3-menu-header">통화</div>
<a class="bp3-menu-item bp3-active" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&currency=EUR">€ EUR</a>
<a class="bp3-menu-item" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&currency=USD">$ USD</a>
<a class="bp3-menu-item" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&currency=GBP">£ GBP</a>
<div class="bp3-menu-header">컬러스키마</div>
<a class="bp3-menu-item bp3-active" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&engine=frostbite">동상</a>
<a class="bp3-menu-item" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&engine=ignite">Ignite</a>
<a class="bp3-menu-item" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&engine=impact">Impact</a>
<div class="bp3-menu-header">잠재력</div>
<a class="bp3-menu-item bp3-active" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&potential=show">보기</a>
<a class="bp3-menu-item" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&potential=hide">숨기기</a>
</div>
</div>
<label class="bp3-button bp3-minimal block" for="theme">
<input id="theme" name="theme" value="light" type="checkbox" class="hide">
<span class="bp3-icon"><svg viewBox="0 0 24 24" width="18" height="18"><path d="M12 18q2.484 0 4.242-1.758t1.758-4.242-1.758-4.242-4.242-1.758q-1.219 0-2.484 0.563 1.547 0.703 2.508 2.18t0.961 3.258-0.961 3.258-2.508 2.18q1.266 0.563 2.484 0.563zM20.016 8.672l3.281 3.328-3.281 3.328v4.688h-4.688l-3.328 3.281-3.328-3.281h-4.688v-4.688l-3.281-3.328 3.281-3.328v-4.688h4.688l3.328-3.281 3.328 3.281h4.688v4.688z"></path></svg></span>
</label>
<a rel="nofollow" href="javascript:void(0);" role="button" class="bp3-button bp3-minimal lang-toggle" tabindex="104"><img title="Korea Republic" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/kr.png" data-srcset="https://cdn.sofifa.net/flags/kr@2x.png 2x, https://cdn.sofifa.net/flags/kr@3x.png 3x" class="flag" width="21" height="16"> <span class="bp3-icon"><svg viewBox="0 0 24 24" width="16" height="16"><polyline points="6 9 12 15 18 9"></polyline></svg></span></a>
</div>
</div>
</nav>
<div id="lang" class="header hide">
<div class="center">
<a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=en-US"><img title="United States" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/us.png" data-srcset="https://cdn.sofifa.net/flags/us@2x.png 2x, https://cdn.sofifa.net/flags/us@3x.png 3x" class="flag" width="21" height="16"> English</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=de-DE"><img title="Germany" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/de.png" data-srcset="https://cdn.sofifa.net/flags/de@2x.png 2x, https://cdn.sofifa.net/flags/de@3x.png 3x" class="flag" width="21" height="16"> Deutsch</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=pt-BR"><img title="Brazil" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/br.png" data-srcset="https://cdn.sofifa.net/flags/br@2x.png 2x, https://cdn.sofifa.net/flags/br@3x.png 3x" class="flag" width="21" height="16"> Português Brasileiro</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=fr-FR"><img title="France" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/fr.png" data-srcset="https://cdn.sofifa.net/flags/fr@2x.png 2x, https://cdn.sofifa.net/flags/fr@3x.png 3x" class="flag" width="21" height="16"> Français</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=es-ES"><img title="Spain" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/es.png" data-srcset="https://cdn.sofifa.net/flags/es@2x.png 2x, https://cdn.sofifa.net/flags/es@3x.png 3x" class="flag" width="21" height="16"> Español</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=it-IT"><img title="Italy" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/it.png" data-srcset="https://cdn.sofifa.net/flags/it@2x.png 2x, https://cdn.sofifa.net/flags/it@3x.png 3x" class="flag" width="21" height="16"> Italiano</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=nl-NL"><img title="Netherlands" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/nl.png" data-srcset="https://cdn.sofifa.net/flags/nl@2x.png 2x, https://cdn.sofifa.net/flags/nl@3x.png 3x" class="flag" width="21" height="16"> Dutch</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=ja-JP"><img title="Japan" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/jp.png" data-srcset="https://cdn.sofifa.net/flags/jp@2x.png 2x, https://cdn.sofifa.net/flags/jp@3x.png 3x" class="flag" width="21" height="16"> 日本語</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=pl-PL"><img title="Poland" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/pl.png" data-srcset="https://cdn.sofifa.net/flags/pl@2x.png 2x, https://cdn.sofifa.net/flags/pl@3x.png 3x" class="flag" width="21" height="16"> Polski</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=tr-TR"><img title="Turkey" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/tr.png" data-srcset="https://cdn.sofifa.net/flags/tr@2x.png 2x, https://cdn.sofifa.net/flags/tr@3x.png 3x" class="flag" width="21" height="16"> Türkçe</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=zh-CN"><img title="China PR" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/cn.png" data-srcset="https://cdn.sofifa.net/flags/cn@2x.png 2x, https://cdn.sofifa.net/flags/cn@3x.png 3x" class="flag" width="21" height="16"> 中文(简体)</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=sv-SE"><img title="Sweden" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/se.png" data-srcset="https://cdn.sofifa.net/flags/se@2x.png 2x, https://cdn.sofifa.net/flags/se@3x.png 3x" class="flag" width="21" height="16"> Svenska</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=ru-RU"><img title="Russia" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/ru.png" data-srcset="https://cdn.sofifa.net/flags/ru@2x.png 2x, https://cdn.sofifa.net/flags/ru@3x.png 3x" class="flag" width="21" height="16"> Русский</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=pt-PT"><img title="Portugal" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/pt.png" data-srcset="https://cdn.sofifa.net/flags/pt@2x.png 2x, https://cdn.sofifa.net/flags/pt@3x.png 3x" class="flag" width="21" height="16"> Português</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=ko-KR"><img title="Korea Republic" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/kr.png" data-srcset="https://cdn.sofifa.net/flags/kr@2x.png 2x, https://cdn.sofifa.net/flags/kr@3x.png 3x" class="flag" width="21" height="16"> 한국어</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=da-DK"><img title="Denmark" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/dk.png" data-srcset="https://cdn.sofifa.net/flags/dk@2x.png 2x, https://cdn.sofifa.net/flags/dk@3x.png 3x" class="flag" width="21" height="16"> Dansk</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=nn-NO"><img title="Norway" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/no.png" data-srcset="https://cdn.sofifa.net/flags/no@2x.png 2x, https://cdn.sofifa.net/flags/no@3x.png 3x" class="flag" width="21" height="16"> Norsk</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=hu-HU"><img title="Hungary" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/hu.png" data-srcset="https://cdn.sofifa.net/flags/hu@2x.png 2x, https://cdn.sofifa.net/flags/hu@3x.png 3x" class="flag" width="21" height="16"> Magyar</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=fi-FI"><img title="Finland" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/fi.png" data-srcset="https://cdn.sofifa.net/flags/fi@2x.png 2x, https://cdn.sofifa.net/flags/fi@3x.png 3x" class="flag" width="21" height="16"> Suomi</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=zh-HK"><img title="Hong Kong" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/hk.png" data-srcset="https://cdn.sofifa.net/flags/hk@2x.png 2x, https://cdn.sofifa.net/flags/hk@3x.png 3x" class="flag" width="21" height="16"> 中文(繁體)</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=uk-UA"><img title="Ukraine" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/ua.png" data-srcset="https://cdn.sofifa.net/flags/ua@2x.png 2x, https://cdn.sofifa.net/flags/ua@3x.png 3x" class="flag" width="21" height="16"> Українська</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=cs-CZ"><img title="Czech Republic" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/cz.png" data-srcset="https://cdn.sofifa.net/flags/cz@2x.png 2x, https://cdn.sofifa.net/flags/cz@3x.png 3x" class="flag" width="21" height="16"> Čeština</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=ar-AA"><img title="Saudi Arabia" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/sa.png" data-srcset="https://cdn.sofifa.net/flags/sa@2x.png 2x, https://cdn.sofifa.net/flags/sa@3x.png 3x" class="flag" width="21" height="16"> العربية</a></div>
</div>
<div class="header"><div class="center">
<div role="banner" class="top-banner"><div data-pw-desk="leaderboard_atf" style="width:728px;height:90px" id="pwDeskLbAtf"></div>
<script>
  window.ramp.que.push(function () {
    window.ramp.addTag("pwDeskLbAtf");
  })
</script></div>
<h1 class="ellipsis">팀</h1>
<h2>
<div class="dropdown">
<a rel="nofollow" href="javascript:void(0);" role="button" class="bp3-button bp3-minim
 13.</a>
<a class="bp3-menu-item" href="/teams?type=club&r=230013&set=true">2023. 2. 7.</a>
<a class="bp3-menu-item" href="/teams?type=club&r=230012&set=true">2023. 1. 30.</a>
<a class="bp3-menu-item" href="/teams?type=club&r=230011&set=true">2023. 1. 25.</a>
<a class="bp3-menu-item" href="/teams?type=club&r=230010&set=true">2023. 1. 18.</a>
<a class="bp3-menu-item" href="/teams?type=club&r=230009&set=true">2023. 1. 13.</a>
<a class="bp3-menu-item" href="/teams?type=club&r=230008&set=true">2022. 12. 17.</a>
<a class="bp3-menu-item" href="/teams?type=club&r=230007&set=true">2022. 12. 6.</a>
<a class="bp3-menu-item" href="/teams?type=club&r=230006&set=true">2022. 11. 16.</a>
<a class="bp3-menu-item" href="/teams?type=club&r=230005&set=true">2022. 10. 28.</a>
<a class="bp3-menu-item" href="/teams?type=club&r=230004&set=true">2022. 10. 7.</a>
<a class="bp3-menu-item" href="/teams?type=club&r=230003&set=true">2022. 9. 28.</a>
<a class="bp3-menu-item" href="/teams?type=club&r=230002&set=true">2022. 9. 26.</a>
<a class="bp3-menu-item" href="/teams?type=club&r=230001&set=true">2022. 9. 1.</a>
<a class="bp3-menu-item" href="/teams?type=club&r=202200&set=true">World Cup 2022</a></div>
</div>
</h2>
</div></div>
<div class="sub-nav"><div class="center">
<form action="/teams" method="get" class="top-search bp3-input-group">
<span class="bp3-icon bp3-icon-search"><svg viewBox="0 0 24 24" width="16" height="16"><circle cx="11" cy="11" r="8"></circle><line x1="21" y1="21" x2="16.65" y2="16.65"></line></svg></span>
<input type="text" class="bp3-input suggest" name="keyword" placeholder="검색팀...">
</form><div class="bp3-tabs">
<div class="bp3-tab-list" role="tablist">
<a class="bp3-tab" role="tab" href="/teams">Trending</a>
<a class="bp3-tab" role="tab" aria-selected="true" href="/teams?type=club">소속팀</a>
<a class="bp3-tab" role="tab" href="/teams?type=national">국가대표팀</a>
</div>
</div></div></div>
</header>
<div class="center">
<div class="grid">
<div class="col col-4">
<form action="/teams?type=club&r=230052&set=true" method="get" class="pjax-select pjax-form">
<div class="card">
<h5>열선택</h5>
<div class="choices-column half-spacing"><select name="showCol[]" class="choices-multiple" data-placeholder="Add column" data-always="true" multiple>
<optgroup label="기본"><option value="ti">ID</option><option value="oa" selected>종합</option><option value="at" selected>공격</option><option value="md" selected>미드필드</option><option value="df" selected>수비</option><option value="tb" selected>이적자금</option><option value="cw">클럽 가치</option></optgroup>
<optgroup label="빌드업 플레이"><option value="bs">속도</option><option value="bd">드리블</option><option value="bp">패스</option><option value="bps">위치 선정</option></optgroup>
<optgroup label="기회 창출"><option value="cc">크로스</option><option value="cp">패스</option><option value="cs">슛</option><option value="cps">위치 선정</option></optgroup>
<optgroup label="수비"><option value="da">적극성</option><option value="dm">압박</option><option value="dw">좌우 폭</option><option value="dd">수비수 선</option></optgroup>
<optgroup label="특별한"><option value="dp">국내 명성/인지도</option><option value="ip">국제 명성/인지도</option><option value="ps" selected>선수</option><option value="sa">XI평균연령시작</option><option value="ta">전체팀평균연령</option></optgroup>
</select>
</div>
<div class="bp3-control-group bp3-fill">
<button class="bp3-button bp3-intent-primary" type="submit">적용</button>
<a class="bp3-button pjax" href="/teams?type=club&r=230052&set=true&showCol=reset">초기화</span></a>
</div>
</div>
</form>
<form action="/teams" class="relative pjax-form" data-pjax="content-target">
<div class="card">
<h5>검색</h5>
<div class="half-spacing grid">
<div class="col col-6">
<label class="ellipsis">이름</label>
</div>
<div class="col col-12">
<input type="text" name="keyword" class="bp3-input bp3-fill" value>
</div>
</div>
<input type="hidden" name="type" value="club">
<div class="half-spacing">
<select id="choices-ct" name="ct[]" data-placeholder="대륙" data-value multiple></select></div>
<div class="half-spacing">
<select id="choices-na" name="na[]" data-placeholder="국적" data-value multiple></select></div>
<div class="half-spacing">
<select id="choices-lg" name="lg[]" data-placeholder="리그" data-value multiple></select></div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">종합</label>
</div>
<div class="col col-3">
<input id="oal" type="number" name="oal" placeholder="0" class="bp3-input min" size="2" max="99" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="oah" type="number" name="oah" placeholder="99" class="bp3-input max" size="2" max="99" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">공격</label>
</div>
<div class="col col-3">
<input id="atl" type="number" name="atl" placeholder="0" class="bp3-input min" size="2" max="99" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="ath" type="number" name="ath" placeholder="99" class="bp3-input max" size="2" max="99" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">미드필드</label>
</div>
<div class="col col-3">
<input id="mdl" type="number" name="mdl" placeholder="0" class="bp3-input min" size="2" max="99" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="mdh" type="number" name="mdh" placeholder="99" class="bp3-input max" size="2" max="99" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">수비</label>
</div>
<div class="col col-3">
<input id="dfl" type="number" name="dfl" placeholder="0" class="bp3-input min" size="2" max="99" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="dfh" type="number" name="dfh" placeholder="99" class="bp3-input max" size="2" max="99" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">국제 명성/인지도</label>
</div>
<div class="col col-3">
<input id="ipl" type="number" name="ipl" placeholder="0" class="bp3-input min" size="2" max="20" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="iph" type="number" name="iph" placeholder="20" class="bp3-input max" size="2" max="20" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">국내 명성/인지도</label>
</div>
<div class="col col-3">
<input id="dpl" type="number" name="dpl" placeholder="0" class="bp3-input min" size="2" max="20" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="dph" type="number" name="dph" placeholder="20" class="bp3-input max" size="2" max="20" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">XI평균연령시작</label>
</div>
<div class="col col-3">
<input id="sal" type="number" name="sal" placeholder="15" class="bp3-input min" size="2" max="45" min="15" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="sah" type="number" name="sah" placeholder="45" class="bp3-input max" size="2" max="45" min="15" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">전체팀평균연령</label>
</div>
<div class="col col-3">
<input id="tal" type="number" name="tal" placeholder="15" class="bp3-input min" size="2" max="45" min="15" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="tah" type="number" name="tah" placeholder="45" class="bp3-input max" size="2" max="45" min="15" value>
</div>
</div>
<div>
<button type="submit" class="bp3-button bp3-intent-primary bp3-fill">제출</button>
</div>
</div>
<div class="card">
<h5>수비</h5>
<div class="half-spacing">
<select name="tds[]" data-placeholder="수비 스타일" class="choices-multiple" multiple>
<option value="0">후퇴</option>
<option value="1">밸런스</option>
<option value="2">볼 터치 실수 시 압박</option>
<option value="3">공을 뺏긴 직후 압박</option>
<option value="4">지속적인 압박</option>
</select>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">좌우 폭</label>
</div>
<div class="col col-3">
<input id="tdwl" type="number" name="tdwl" placeholder="0" class="bp3-input min" size="2" max="10" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="tdwh" type="number" name="tdwh" placeholder="10" class="bp3-input max" size="2" max="10" min="0" value>
</div>
</div>
<div class="grid spacing">
<div class="col col-9">
<label class="ellipsis">깊이</label>
</div>
<div class="col col-3">
<input id="tddl" type="number" name="tddl" placeholder="0" class="bp3-input min" size="2" max="10" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="tddh" type="number" name="tddh" placeholder="10" class="bp3-input max" size="2" max="10" min="0" value>
</div>
</div>
<h5>공격</h5>
<div class="half-spacing">
<select name="tbp[]" data-placeholder="빌드업 플레이" class="choices-multiple" multiple>
<option value="0">느린 빌드업</option>
<option value="1">빠른 빌드업</option>
<option value="2">긴 패스</option>
<option value="3">밸런스</option>
<option value="4">점유율</option>
</select>
</div>
<div class="half-spacing">
<select name="tcc[]" data-placeholder="기회 창출" class="choices-multiple" multiple>
<option value="0">점유율</option>
<option value="1">전방 달리기</option>
<option value="2">직접 패스</option>
<option value="3">밸런스</option>
</select>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">폭</label>
</div>
<div class="col col-3">
<input id="towl" type="number" name="towl" placeholder="0" class="bp3-input min" size="2" max="10" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="towh" type="number" name="towh" placeholder="10" class="bp3-input max" size="2" max="10" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">박스 안쪽 선수</label>
</div>
<div class="col col-3">
<input id="tpcl" type="number" name="tpcl" placeholder="0" class="bp3-input min" size="2" max="10" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="tpch" type="number" name="tpch" placeholder="10" class="bp3-input max" size="2" max="10" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">코너킥</label>
</div>
<div class="col col-3">
<input id="tprl" type="number" name="tprl" placeholder="0" class="bp3-input min" size="2" max="5" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="tprh" type="number" name="tprh" placeholder="5" class="bp3-input max" size="2" max="5" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">프리킥</label>
</div>
<div class="col col-3">
<input id="tpfl" type="number" name="tpfl" placeholder="0" class="bp3-input min" size="2" max="5" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="tpfh" type="number" name="tpfh" placeholder="5" class="bp3-input max" size="2" max="5" min="0" value>
</div>
</div>
<div>
<button type="submit" class="bp3-button bp3-intent-primary bp3-fill">제출</button>
</div>
</div>
</form><div class="left-banner double-spacing sticky">
<div data-pw-desk="med_rect_btf" id="pwDeskMedRectBtf1"></div>
<script>
window.ramp.que.push(function () {
window.ramp.addTag("pwDeskMedRectBtf1");
})
</script>
</div>
</div>
<div class="col col-12">
<div class="card">
<table class="table table-hover persist-area">
<thead>
<tr class="persist-header">
<th class="col-avatar"></th>
<th class="col-name-wide text-left">이름</th><th class="tooltip col col-oa" data-tooltip="종합"><a rel="nofollow" class="ellipsis pjax" href="/teams?type=club&r=230052&set=true&col=oa&sort=desc"><span class="bp3-icon sorter"></span>종합 </a></th><th class="tooltip col col-at" data-tooltip="공격"><a rel="nofollow" class="ellipsis pjax" href="/teams?type=club&r=230052&set=true&col=at&sort=desc"><span class="bp3-icon sorter"></span>공격 </a></th><th class="tooltip col col-md" data-tooltip="미드필드"><a rel="nofollow" class="ellipsis pjax" href="/teams?type=club&r=230052&set=true&col=md&sort=desc"><span class="bp3-icon sorter"></span>미드필드 </a></th><th class="tooltip col col-df" data-tooltip="수비"><a rel="nofollow" class="ellipsis pjax" href="/teams?type=club&r=230052&set=true&col=df&sort=desc"><span class="bp3-icon sorter"></span>수비 </a></th><th class="tooltip col col-tb" data-tooltip="이적자금"><a rel="nofollow" class="ellipsis pjax" href="/teams?type=club&r=230052&set=true&col=tb&sort=desc"><span class="bp3-icon sorter"></span>이적자금 </a></th><th class="tooltip col col-ps" data-tooltip="선수"><a rel="nofollow" class="ellipsis pjax" href="/teams?type=club&r=230052&set=true&col=ps&sort=desc"><span class="bp3-icon sorter"></span>선수 </a></th></tr>
</thead>
<tbody><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/9/60.png" data-srcset="https://cdn.sofifa.net/meta/team/9/120.png 2x, https://cdn.sofifa.net/meta/team/9/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/10/manchester-city/"><div class="ellipsis">Manchester City</div></a><a href="/teams?lg=13" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=14" title="England"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/gb-eng.png" data-srcset="https://cdn.sofifa.net/flags/gb-eng@2x.png 2x, https://cdn.sofifa.net/flags/gb-eng@3x.png 3x" class="flag" width="21" height="16"></a> Premier League</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-85">85</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-85">85</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-87">87</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-83">83</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">26</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/503/60.png" data-srcset="https://cdn.sofifa.net/meta/team/503/120.png 2x, https://cdn.sofifa.net/meta/team/503/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/21/fc-bayern-munchen/"><div class="ellipsis">FC Bayern München</div></a><a href="/teams?lg=19" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=21" title="Germany"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/de.png" data-srcset="https://cdn.sofifa.net/flags/de@2x.png 2x, https://cdn.sofifa.net/flags/de@3x.png 3x" class="flag" width="21" height="16"></a> Bundesliga</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-85">85</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-86">86</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-85">85</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-83">83</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">31</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/3468/60.png" data-srcset="https://cdn.sofifa.net/meta/team/3468/120.png 2x, https://cdn.sofifa.net/meta/team/3468/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/243/real-madrid/"><div class="ellipsis">Real Madrid</div></a><a href="/teams?lg=53" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=45" title="Spain"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/es.png" data-srcset="https://cdn.sofifa.net/flags/es@2x.png 2x, https://cdn.sofifa.net/flags/es@3x.png 3x" class="flag" width="21" height="16"></a> La Liga</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-85">85</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-85">85</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-86">86</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-84">84</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">33</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/8/60.png" data-srcset="https://cdn.sofifa.net/meta/team/8/120.png 2x, https://cdn.sofifa.net/meta/team/8/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/9/liverpool/"><div class="ellipsis">Liverpool</div></a><a href="/teams?lg=13" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=14" title="England"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/gb-eng.png" data-srcset="https://cdn.sofifa.net/flags/gb-eng@2x.png 2x, https://cdn.sofifa.net/flags/gb-eng@3x.png 3x" class="flag" width="21" height="16"></a> Premier League</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-84">84</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-84">84</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-81">81</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-85">85</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">33</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/591/60.png" data-srcset="https://cdn.sofifa.net/meta/team/591/120.png 2x, https://cdn.sofifa.net/meta/team/591/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/73/paris-saint-germain/"><div class="ellipsis">Paris Saint Germain</div></a><a href="/teams?lg=16" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=18" title="France"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/fr.png" data-srcset="https://cdn.sofifa.net/flags/fr@2x.png 2x, https://cdn.sofifa.net/flags/fr@3x.png 3x" class="flag" width="21" height="16"></a> Ligue 1</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-84">84</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-86">86</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-79">79</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-82">82</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">27</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/7980/60.png" data-srcset="https://cdn.sofifa.net/meta/team/7980/120.png 2x, https://cdn.sofifa.net/meta/team/7980/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/240/atletico-madrid/"><div class="ellipsis">Atlético Madrid</div></a><a href="/teams?lg=53" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=45" title="Spain"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/es.png" data-srcset="https://cdn.sofifa.net/flags/es@2x.png 2x, https://cdn.sofifa.net/flags/es@3x.png 3x" class="flag" width="21" height="16"></a> La Liga</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-83">83</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-84">84</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-83">83</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-81">81</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">33</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/83/60.png" data-srcset="https://cdn.sofifa.net/meta/team/83/120.png 2x, https://cdn.sofifa.net/meta/team/83/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/241/fc-barcelona/"><div class="ellipsis">FC Barcelona</div></a><a href="/teams?lg=53" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=45" title="Spain"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/es.png" data-srcset="https://cdn.sofifa.net/flags/es@2x.png 2x, https://cdn.sofifa.net/flags/es@3x.png 3x" class="flag" width="21" height="16"></a> La Liga</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-83">83</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-83">83</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-85">85</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-82">82</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">33</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/19/60.png" data-srcset="https://cdn.sofifa.net/meta/team/19/120.png 2x, https://cdn.sofifa.net/meta/team/19/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/1/arsenal/"><div class="ellipsis">Arsenal</div></a><a href="/teams?lg=13" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=14" title="England"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/gb-eng.png" data-srcset="https://cdn.sofifa.net/flags/gb-eng@2x.png 2x, https://cdn.sofifa.net/flags/gb-eng@3x.png 3x" class="flag" width="21" height="16"></a> Premier League</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p
180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/1799/crystal-palace/"><div class="ellipsis">Crystal Palace</div></a><a href="/teams?lg=13" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=14" title="England"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/gb-eng.png" data-srcset="https://cdn.sofifa.net/flags/gb-eng@2x.png 2x, https://cdn.sofifa.net/flags/gb-eng@3x.png 3x" class="flag" width="21" height="16"></a> Premier League</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-76">76</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-76">76</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-76">76</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-76">76</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">31</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/1024/60.png" data-srcset="https://cdn.sofifa.net/meta/team/1024/120.png 2x, https://cdn.sofifa.net/meta/team/1024/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/1043/flamengo/"><div class="ellipsis">Flamengo</div></a><a href="/teams?lg=7" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=54" title="Brazil"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/br.png" data-srcset="https://cdn.sofifa.net/flags/br@2x.png 2x, https://cdn.sofifa.net/flags/br@3x.png 3x" class="flag" width="21" height="16"></a> Serie A</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-76">76</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-77">77</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-75">75</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-75">75</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">20</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/3543/60.png" data-srcset="https://cdn.sofifa.net/meta/team/3543/120.png 2x, https://cdn.sofifa.net/meta/team/3543/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/25/sc-freiburg/"><div class="ellipsis">SC Freiburg</div></a><a href="/teams?lg=19" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=21" title="Germany"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/de.png" data-srcset="https://cdn.sofifa.net/flags/de@2x.png 2x, https://cdn.sofifa.net/flags/de@3x.png 3x" class="flag" width="21" height="16"></a> Bundesliga</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-76">76</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-76">76</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-76">76</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-77">77</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">25</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/2726/60.png" data-srcset="https://cdn.sofifa.net/meta/team/2726/120.png 2x, https://cdn.sofifa.net/meta/team/2726/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/10029/tsg-hoffenheim/"><div class="ellipsis">TSG Hoffenheim</div></a><a href="/teams?lg=19" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=21" title="Germany"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/de.png" data-srcset="https://cdn.sofifa.net/flags/de@2x.png 2x, https://cdn.sofifa.net/flags/de@3x.png 3x" class="flag" width="21" height="16"></a> Bundesliga</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-76">76</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-76">76</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-78">78</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-76">76</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">33</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/271/60.png" data-srcset="https://cdn.sofifa.net/meta/team/271/120.png 2x, https://cdn.sofifa.net/meta/team/271/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/64/lens/"><div class="ellipsis">Lens</div></a><a href="/teams?lg=16" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=18" title="France"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/fr.png" data-srcset="https://cdn.sofifa.net/flags/fr@2x.png 2x, https://cdn.sofifa.net/flags/fr@3x.png 3x" class="flag" width="21" height="16"></a> Ligue 1</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-76">76</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-77">77</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-76">76</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-77">77</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">29</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/690/60.png" data-srcset="https://cdn.sofifa.net/meta/team/690/120.png 2x, https://cdn.sofifa.net/meta/team/690/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/65/lille/"><div class="ellipsis">Lille</div></a><a href="/teams?lg=16" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=18" title="France"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/fr.png" data-srcset="https://cdn.sofifa.net/flags/fr@2x.png 2x, https://cdn.sofifa.net/flags/fr@3x.png 3x" class="flag" width="21" height="16"></a> Ligue 1</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-76">76</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-78">78</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-76">76</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-76">76</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">23</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/450/60.png" data-srcset="https://cdn.sofifa.net/meta/team/450/120.png 2x, https://cdn.sofifa.net/meta/team/450/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/72/nice/"><div class="ellipsis">Nice</div></a><a href="/teams?lg=16" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=18" title="France"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/fr.png" data-srcset="https://cdn.sofifa.net/flags/fr@2x.png 2x, https://cdn.sofifa.net/flags/fr@3x.png 3x" class="flag" width="21" height="16"></a> Ligue 1</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-76">76</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-75">75</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-76">76</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-76">76</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">26</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/10002/60.png" data-srcset="https://cdn.sofifa.net/meta/team/10002/120.png 2x, https://cdn.sofifa.net/meta/team/10002/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/1876/river-plate/"><div class="ellipsis">River Plate</div></a><a href="/teams?lg=353" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=52" title="Argentina"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/ar.png" data-srcset="https://cdn.sofifa.net/flags/ar@2x.png 2x, https://cdn.sofifa.net/flags/ar@3x.png 3x" class="flag" width="21" height="16"></a> Liga Profesional</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-76">76</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-75">75</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-77">77</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-75">75</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">28</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/884/60.png" data-srcset="https://cdn.sofifa.net/meta/team/884/120.png 2x, https://cdn.sofifa.net/meta/team/884/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/1896/sporting-braga/"><div class="ellipsis">Sporting Braga</div></a><a href="/teams?lg=308" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=38" title="Portugal"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/pt.png" data-srcset="https://cdn.sofifa.net/flags/pt@2x.png 2x, https://cdn.sofifa.net/flags/pt@3x.png 3x" class="flag" width="21" height="16"></a> Liga Portugal</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-76">76</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-78">78</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-77">77</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-75">75</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">30</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/3422/60.png" data-srcset="https://cdn.sofifa.net/meta/team/3422/120.png 2x, https://cdn.sofifa.net/meta/team/3422/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/383/palmeiras/"><div class="ellipsis">Palmeiras</div></a><a href="/teams?lg=7" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=54" title="Brazil"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/br.png" data-srcset="https://cdn.sofifa.net/flags/br@2x.png 2x, https://cdn.sofifa.net/flags/br@3x.png 3x" class="flag" width="21" height="16"></a> Serie A</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-76">76</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-78">78</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-77">77</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-74">74</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">20</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/11/60.png" data-srcset="https://cdn.sofifa.net/meta/team/11/120.png 2x, https://cdn.sofifa.net/meta/team/11/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/144/fulham/"><div class="ellipsis">Fulham</div></a><a href="/teams?lg=13" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=14" title="England"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/gb-eng.png" data-srcset="https://cdn.sofifa.net/flags/gb-eng@2x.png 2x, https://cdn.sofifa.net/flags/gb-eng@3x.png 3x" class="flag" width="21" height="16"></a> Premier League</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-76">76</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-79">79</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-76">76</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-75">75</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">31</td></tr></tbody>
</table>
<div class="pagination">
<a href="/teams?type=club&r=230052&set=true&offset=60" class="bp3-button bp3-intent-primary pjax"><span class="bp3-button-text">다음</span><span class="bp3-icon bp3-icon-chevron-right"><svg viewBox="0 0 24 24" width="16" height="16"><polyline points="9 18 15 12 9 6"></polyline></svg></span></a>
</div>
</div>
</div>
</div>
</div>
<footer>
<div class="center"><p class="copyright">All product names, logos, and brands are the property of their respective owners.<br>All company, product, and service names used in this website are for identification purposes only.<br><a href="/help/tos">자귀</a>&nbsp;&nbsp;<a href="/help/privacy">은둔</a>&nbsp;&nbsp;<a href="/help/faq">FAQ</a></p></div>
</footer>
<div id="sign-in-form" class="hide"><div class="bp3-dialog-header"><h4 class="bp3-heading">로그인</h4><button type="button" class="bp3-button bp3-minimal bp3-dialog-close-button btn-cancel"><span icon="small-cross" class="bp3-icon bp3-icon-small-cross"><svg viewBox="0 0 24 24" width="20" height="20"><line x1="18" y1="6" x2="6" y2="18"></line><line x1="6" y1="6" x2="18" y2="18"></line></svg></span></button></div><div class="bp3-dialog-body"><form method="post" action="/signIn" class="ajax-form"><div class="bp3-form-group bp3-inline"><input class="bp3-input bp3-fill" type="text" name="email" placeholder="이메일"></div><div class="bp3-form-group bp3-inline"><input class="bp3-input bp3-fill" type="password" name="password" placeholder="암호"></div><div class="bp3-form-group bp3-inline spacing"><div class="bp3-full-width text-right"><a href="/signUp" class="bp3-button bp3-minimal sign-up">가입하기</a><a href="/forgot" class="bp3-button bp3-minimal forgot">비밀번호를잊으셨나요</a>&nbsp;&nbsp;<button type="submit" name="submit" class="bp3-button">로그인</button></div></div><div class="bp3-divider spacing"></div><div class="bp3-form-group bp3-inline"><a class="bp3-button google compact" rel="nofollow" href="/authorize/google" role="tooltip" data-tip-pos="top" aria-label="Google로로그인"><svg xmlns="http://www.w3.org/2000/svg" width="20" height="20" viewBox
67 1.2 424.58 424.58 0 0 0 127.85 64.63 1.66 1.66 0 0 0 1.8-.59 303.45 303.45 0 0 0 26.15-42.54 1.62 1.62 0 0 0-.89-2.25 279.6 279.6 0 0 1-39.94-19 1.64 1.64 0 0 1-.16-2.72c2.68-2 5.37-4.1 7.93-6.22a1.58 1.58 0 0 1 1.65-.22c83.79 38.26 174.51 38.26 257.31 0a1.58 1.58 0 0 1 1.68.2c2.56 2.11 5.25 4.23 8 6.24a1.64 1.64 0 0 1-.14 2.72 262.37 262.37 0 0 1-40 19 1.63 1.63 0 0 0-.87 2.28 340.72 340.72 0 0 0 26.13 42.52 1.62 1.62 0 0 0 1.8.61 423.17 423.17 0 0 0 128-64.63 1.64 1.64 0 0 0 .67-1.18c10.68-110.44-17.88-206.38-75.7-291.42a1.3 1.3 0 0 0-.63-.63zM427.09 582.85c-25.23 0-46-23.16-46-51.6s20.38-51.6 46-51.6c25.83 0 46.42 23.36 46 51.6.02 28.44-20.37 51.6-46 51.6zm170.13 0c-25.23 0-46-23.16-46-51.6s20.38-51.6 46-51.6c25.83 0 46.42 23.36 46 51.6.01 28.44-20.17 51.6-46 51.6z" style="fill:#fff" /></svg></a></div></form></div></div>
<div id="sign-up-form" class="hide"><div class="bp3-dialog-header"><h4 class="bp3-heading">가입하기</h4><button type="button" class="bp3-button bp3-minimal bp3-dialog-close-button btn-cancel"><span icon="small-cross" class="bp3-icon bp3-icon-small-cross"><svg viewBox="0 0 24 24" width="20" height="20"><line x1="18" y1="6" x2="6" y2="18"></line><line x1="6" y1="6" x2="18" y2="18"></line></svg></span></button></div><div class="bp3-dialog-body"><form method="post" action="/signUp" data-next="/teams" class="ajax-form"><div class="bp3-form-group bp3-inline"><input class="bp3-input bp3-fill" type="text" name="email" placeholder="이메일"></div><div class="bp3-form-group bp3-inline"><input class="bp3-input bp3-fill" type="text" name="name" placeholder="이름"></div><div class="bp3-form-group bp3-inline"><input class="bp3-input bp3-fill" type="password" name="password" id="password" placeholder="암호"></div><div class="bp3-form-group bp3-inline"><input class="bp3-input bp3-fill" type="password" name="confirmPassword" placeholder="비밀번호확인"></div><div class="bp3-form-group bp3-inline spacing"><div class="bp3-full-width text-right"><button type="submit" name="submit" class="bp3-button">제출</button></div></div></form></div></div>
<div id="forgot-form" class="hide"><div class="bp3-dialog-header"><h4 class="bp3-heading">비밀번호를잊으셨나요</h4><button type="button" class="bp3-button bp3-minimal bp3-dialog-close-button btn-cancel"><span icon="small-cross" class="bp3-icon bp3-icon-small-cross"><svg viewBox="0 0 24 24" width="20" height="20"><line x1="18" y1="6" x2="6" y2="18"></line><line x1="6" y1="6" x2="18" y2="18"></line></svg></span></button></div><div class="bp3-dialog-body"><form method="post" action="/forgot" class="ajax-form"><div class="bp3-form-group bp3-inline">이메일을제공해주세요.추가지침이포함된이메일을보내드리겠습니다.</div><div class="bp3-form-group bp3-inline"><input class="bp3-input bp3-fill" type="text" name="email" placeholder="이메일"></div><div class="bp3-form-group bp3-inline"><div class="bp3-full-width text-right"><button type="submit" name="submit" class="bp3-button">제출</button></div></div></form></div></div>
<script src="https://static.sofifa.net/js/desktop.min.js?20"></script>
<script defer src="https://static.sofifa.net/js/socket.min.js?2"></script>
<script defer src="https://static.sofifa.net/js/uploader.min.js?2"></script>
<script defer src="https://static.sofifa.net/js/comment.min.js?29"></script>
<script async src="https://cdn.intergient.com/1024268/72628/ramp_config.js"></script>
<script async src="https://static.sofifa.net/js/ramp.min.js?2"></script>
<script async src="https://cdn.intergient.com/ramp_core.js"></script>
<script async src="https://www.googletagmanager.com/gtag/js?id=G-X81LWDNFGR"></script>
<script>window.dataLayer = window.dataLayer || [];function gtag(){dataLayer.push(arguments);}gtag('js', new Date());gtag('config', 'G-X81LWDNFGR');</script>
</body>
</html>'''

# %%
html2 = '''

<!DOCTYPE html>
<html lang="ko-KR">
<head id="head">
<title>팀 FIFA 23 2023. 8. 24. SoFIFA</title>
<meta charset="utf-8">
<meta name="viewport" content="width=device-width, initial-scale=1">
<meta name="google-site-verification" content="VGaFvm9Qm-qhCd2LCDi8QKWXNPSrVE2SJ2iT8c3vI1g">
<meta name="description" content="2023. 8. 24. FIFA 23 팀 평점">
<meta name="copyright" content="2009 - 2023 SoFIFA.com">
<meta name="twitter:widgets:theme" content="dark">
<meta name="twitter:widgets:border-color" content="#777777">
<link rel="shortcut icon" href="https://static.sofifa.net/launcher-icon.png">
<link rel="apple-touch-icon" href="https://static.sofifa.net/launcher-icon.png">
<link rel="preconnect" href="https://cdn.intergient.com/" crossorigin>
<link rel="dns-prefetch" href="https://cdn.intergient.com/">
<script>window.ramp = window.ramp || {};window.ramp.que = window.ramp.que || [];</script>
<link rel="alternate" hreflang="en" href="https://sofifa.com/teams?hl=en-US">
<link rel="alternate" hreflang="fr" href="https://sofifa.com/teams?hl=fr-FR">
<link rel="alternate" hreflang="de" href="https://sofifa.com/teams?hl=de-DE">
<link rel="alternate" hreflang="es" href="https://sofifa.com/teams?hl=es-ES">
<link rel="alternate" hreflang="it" href="https://sofifa.com/teams?hl=it-IT">
<link rel="alternate" hreflang="pt-BR" href="https://sofifa.com/teams?hl=pt-BR">
<link rel="alternate" hreflang="nl" href="https://sofifa.com/teams?hl=nl-NL">
<link rel="alternate" hreflang="ko" href="https://sofifa.com/teams?hl=ko-KR">
<link rel="alternate" hreflang="pl" href="https://sofifa.com/teams?hl=pl-PL">
<link rel="alternate" hreflang="zh-CN" href="https://sofifa.com/teams?hl=zh-CN">
<link rel="alternate" hreflang="ru" href="https://sofifa.com/teams?hl=ru-RU">
<link rel="alternate" hreflang="ja" href="https://sofifa.com/teams?hl=ja-JP">
<link rel="alternate" hreflang="sv" href="https://sofifa.com/teams?hl=sv-SE">
<link rel="alternate" hreflang="da" href="https://sofifa.com/teams?hl=da-DK">
<link rel="alternate" hreflang="pt-PT" href="https://sofifa.com/teams?hl=pt-PT">
<link rel="alternate" hreflang="nn" href="https://sofifa.com/teams?hl=nn-NO">
<link rel="alternate" hreflang="hu" href="https://sofifa.com/teams?hl=hu-HU">
<link rel="alternate" hreflang="cs" href="https://sofifa.com/teams?hl=cs-CZ">
<link rel="alternate" hreflang="fi" href="https://sofifa.com/teams?hl=fi-FI">
<link rel="alternate" hreflang="uk" href="https://sofifa.com/teams?hl=uk-UA">
<link rel="alternate" hreflang="tr" href="https://sofifa.com/teams?hl=tr-TR">
<link rel="alternate" hreflang="zh-HK" href="https://sofifa.com/teams?hl=zh-HK">
<link rel="alternate" hreflang="ar" href="https://sofifa.com/teams?hl=ar-AA"><link rel="canonical" href="https://sofifa.com/teams"><link rel="stylesheet" href="https://static.sofifa.net/css/desktop.min.css?39">
<script>let CDN='https://cdn.sofifa.net',CDN_VERSION='20210431',HL='ko-KR',THEME='dark',GENDER=0,IS_MOBILE=false,USER_ID=0,USER_AVATAR='https://cdn.sofifa.net/avatar?name=Guest',BLOCK='블록',UNBLOCK='차단해제',FOLLOW='따르다',UNFOLLOW='팔로우해제',CHOOSE_FILE='파일을선택...',UPLOADING='업로드중...',CHANGE='변화',UPDATED='업데이트',DELETE_CONFIRM='이항목을제거하시겠습니까?',CANCEL='취소',OK='OK',CLOSE='닫기',BLOCK_CONFIRM='이사용자를차단하시겠습니까?<br>나중에\"내관계\"섹션에서설정을변경할수있습니다.',HISTORY_VERSION='역사버전',VERSION='23', ROSTER='230052',FONT=14,LOAD_MORE_COMMENTS='Load more comments',ADD_A_COMMENT='Add a comment',SORT_BY_NEWEST='Sort by newest',SORT_BY_BEST='Sort by best',MY_COMMENTS='My comments',POST='Post',JUST_NOW='just now',COLLAPSE_REPLIES='Collapse replies',COPY_URL='Copy URL',REPORT='신고',UPVOTE='Upvote',DOWNVOTE='Downvote',EDIT='Edit',REPLY='Reply',APPROVE='Approve',REMOVE='없애다',SHOW_FULL_COMMENT='Show full comment',LOAD_IMAGE='Load image',CANCEL_REPLY='Cancel reply',REPLY_TO_THIS_COMMENT='Reply to this comment',CANCEL_EDIT='Cancel edit',EDIT_THIS_COMMENT='Edit this comment',EXPAND_REPLIES='Expand replies',PLEASE_CHOOSE_A_REASON='Please choose a reason',RACISM='Racism',INSULT='Insult',SPAMMING='Spamming',PORN='Porn',PRIVATE_INFO='Private info',OTHER='기타',DESCRIPTION_OPTIONAL='Description (optional)',SAVING='Saving ...',OPERATION_SUCCEED='작업성공',TYPE_TO_SEARCH='검색할유형',AI_MODERATION=1;</script>
</head>
<body class="is-preload  dark" data-class="is-preload  dark" lang="ko-KR" id="body">
<header>
<nav class="bp3-navbar">
<div class="center">
<div class="bp3-navbar-group bp3-align-left reset">
<div class="bp3-navbar-heading">
<a href="/" rel="nofollow"><img alt="SoFIFA" src="https://cdn.sofifa.net/images/launcher-icon.png" width="30" height="30"></a>
</div>
<a href="/players" class="bp3-button bp3-minimal">선수</a>
<a href="/teams" class="bp3-button bp3-minimal">팀</a>
<a href="/squads" class="bp3-button bp3-minimal">분대</a>
<a href="/shortlists" class="bp3-button bp3-minimal">명단</a>
<a rel="nofollow" href="/discussion/1" class="bp3-button bp3-minimal">토론</a>
</div>
<div class="bp3-navbar-group bp3-align-right">
<a rel="nofollow" href="/signIn" role="button" class="bp3-button bp3-minimal need-sign-in" tabindex="101">로그인</a>
<div class="dropdown dropdown-right">
<a rel="nofollow" href="javascript:void(0);" role="button" class="bp3-button bp3-minimal block dropdown-toggle" tabindex="102" title="설정"><span class="bp3-icon"><svg viewBox="0 0 24 24" width="18" height="18"><circle cx="12" cy="12" r="3"></circle><path d="M19.4 15a1.65 1.65 0 0 0 .33 1.82l.06.06a2 2 0 0 1 0 2.83 2 2 0 0 1-2.83 0l-.06-.06a1.65 1.65 0 0 0-1.82-.33 1.65 1.65 0 0 0-1 1.51V21a2 2 0 0 1-2 2 2 2 0 0 1-2-2v-.09A1.65 1.65 0 0 0 9 19.4a1.65 1.65 0 0 0-1.82.33l-.06.06a2 2 0 0 1-2.83 0 2 2 0 0 1 0-2.83l.06-.06a1.65 1.65 0 0 0 .33-1.82 1.65 1.65 0 0 0-1.51-1H3a2 2 0 0 1-2-2 2 2 0 0 1 2-2h.09A1.65 1.65 0 0 0 4.6 9a1.65 1.65 0 0 0-.33-1.82l-.06-.06a2 2 0 0 1 0-2.83 2 2 0 0 1 2.83 0l.06.06a1.65 1.65 0 0 0 1.82.33H9a1.65 1.65 0 0 0 1-1.51V3a2 2 0 0 1 2-2 2 2 0 0 1 2 2v.09a1.65 1.65 0 0 0 1 1.51 1.65 1.65 0 0 0 1.82-.33l.06-.06a2 2 0 0 1 2.83 0 2 2 0 0 1 0 2.83l-.06.06a1.65 1.65 0 0 0-.33 1.82V9a1.65 1.65 0 0 0 1.51 1H21a2 2 0 0 1 2 2 2 2 0 0 1-2 2h-.09a1.65 1.65 0 0 0-1.51 1z"></path></svg></span></a>
<div class="bp3-menu">
<div class="bp3-menu-header">성별</div>
<a class="bp3-menu-item bp3-active" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&gender=0">Men</a>
<a class="bp3-menu-item" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&gender=1">Women</a>
<div class="bp3-menu-header">단위</div>
<a class="bp3-menu-item" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&units=imperial">피트인치/파운드</a>
<a class="bp3-menu-item bp3-active" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&units=mks">cm / kg</a>
<div class="bp3-menu-header">통화</div>
<a class="bp3-menu-item bp3-active" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&currency=EUR">€ EUR</a>
<a class="bp3-menu-item" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&currency=USD">$ USD</a>
<a class="bp3-menu-item" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&currency=GBP">£ GBP</a>
<div class="bp3-menu-header">컬러스키마</div>
<a class="bp3-menu-item bp3-active" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&engine=frostbite">동상</a>
<a class="bp3-menu-item" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&engine=ignite">Ignite</a>
<a class="bp3-menu-item" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&engine=impact">Impact</a>
<div class="bp3-menu-header">잠재력</div>
<a class="bp3-menu-item bp3-active" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&potential=show">보기</a>
<a class="bp3-menu-item" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&potential=hide">숨기기</a>
</div>
</div>
<label class="bp3-button bp3-minimal block" for="theme">
<input id="theme" name="theme" value="light" type="checkbox" class="hide">
<span class="bp3-icon"><svg viewBox="0 0 24 24" width="18" height="18"><path d="M12 18q2.484 0 4.242-1.758t1.758-4.242-1.758-4.242-4.242-1.758q-1.219 0-2.484 0.563 1.547 0.703 2.508 2.18t0.961 3.258-0.961 3.258-2.508 2.18q1.266 0.563 2.484 0.563zM20.016 8.672l3.281 3.328-3.281 3.328v4.688h-4.688l-3.328 3.281-3.328-3.281h-4.688v-4.688l-3.281-3.328 3.281-3.328v-4.688h4.688l3.328-3.281 3.328 3.281h4.688v4.688z"></path></svg></span>
</label>
<a rel="nofollow" href="javascript:void(0);" role="button" class="bp3-button bp3-minimal lang-toggle" tabindex="104"><img title="Korea Republic" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/kr.png" data-srcset="https://cdn.sofifa.net/flags/kr@2x.png 2x, https://cdn.sofifa.net/flags/kr@3x.png 3x" class="flag" width="21" height="16"> <span class="bp3-icon"><svg viewBox="0 0 24 24" width="16" height="16"><polyline points="6 9 12 15 18 9"></polyline></svg></span></a>
</div>
</div>
</nav>
<div id="lang" class="header hide">
<div class="center">
<a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=en-US"><img title="United States" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/us.png" data-srcset="https://cdn.sofifa.net/flags/us@2x.png 2x, https://cdn.sofifa.net/flags/us@3x.png 3x" class="flag" width="21" height="16"> English</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=de-DE"><img title="Germany" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/de.png" data-srcset="https://cdn.sofifa.net/flags/de@2x.png 2x, https://cdn.sofifa.net/flags/de@3x.png 3x" class="flag" width="21" height="16"> Deutsch</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=pt-BR"><img title="Brazil" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/br.png" data-srcset="https://cdn.sofifa.net/flags/br@2x.png 2x, https://cdn.sofifa.net/flags/br@3x.png 3x" class="flag" width="21" height="16"> Português Brasileiro</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=fr-FR"><img title="France" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/fr.png" data-srcset="https://cdn.sofifa.net/flags/fr@2x.png 2x, https://cdn.sofifa.net/flags/fr@3x.png 3x" class="flag" width="21" height="16"> Français</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=es-ES"><img title="Spain" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/es.png" data-srcset="https://cdn.sofifa.net/flags/es@2x.png 2x, https://cdn.sofifa.net/flags/es@3x.png 3x" class="flag" width="21" height="16"> Español</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=it-IT"><img title="Italy" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/it.png" data-srcset="https://cdn.sofifa.net/flags/it@2x.png 2x, https://cdn.sofifa.net/flags/it@3x.png 3x" class="flag" width="21" height="16"> Italiano</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=nl-NL"><img title="Netherlands" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/nl.png" data-srcset="https://cdn.sofifa.net/flags/nl@2x.png 2x, https://cdn.sofifa.net/flags/nl@3x.png 3x" class="flag" width="21" height="16"> Dutch</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=ja-JP"><img title="Japan" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/jp.png" data-srcset="https://cdn.sofifa.net/flags/jp@2x.png 2x, https://cdn.sofifa.net/flags/jp@3x.png 3x" class="flag" width="21" height="16"> 日本語</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=pl-PL"><img title="Poland" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/pl.png" data-srcset="https://cdn.sofifa.net/flags/pl@2x.png 2x, https://cdn.sofifa.net/flags/pl@3x.png 3x" class="flag" width="21" height="16"> Polski</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=tr-TR"><img title="Turkey" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/tr.png" data-srcset="https://cdn.sofifa.net/flags/tr@2x.png 2x, https://cdn.sofifa.net/flags/tr@3x.png 3x" class="flag" width="21" height="16"> Türkçe</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=zh-CN"><img title="China PR" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/cn.png" data-srcset="https://cdn.sofifa.net/flags/cn@2x.png 2x, https://cdn.sofifa.net/flags/cn@3x.png 3x" class="flag" width="21" height="16"> 中文(简体)</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=sv-SE"><img title="Sweden" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/se.png" data-srcset="https://cdn.sofifa.net/flags/se@2x.png 2x, https://cdn.sofifa.net/flags/se@3x.png 3x" class="flag" width="21" height="16"> Svenska</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=ru-RU"><img title="Russia" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/ru.png" data-srcset="https://cdn.sofifa.net/flags/ru@2x.png 2x, https://cdn.sofifa.net/flags/ru@3x.png 3x" class="flag" width="21" height="16"> Русский</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=pt-PT"><img title="Portugal" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/pt.png" data-srcset="https://cdn.sofifa.net/flags/pt@2x.png 2x, https://cdn.sofifa.net/flags/pt@3x.png 3x" class="flag" width="21" height="16"> Português</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=ko-KR"><img title="Korea Republic" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/kr.png" data-srcset="https://cdn.sofifa.net/flags/kr@2x.png 2x, https://cdn.sofifa.net/flags/kr@3x.png 3x" class="flag" width="21" height="16"> 한국어</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=da-DK"><img title="Denmark" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/dk.png" data-srcset="https://cdn.sofifa.net/flags/dk@2x.png 2x, https://cdn.sofifa.net/flags/dk@3x.png 3x" class="flag" width="21" height="16"> Dansk</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=nn-NO"><img title="Norway" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/no.png" data-srcset="https://cdn.sofifa.net/flags/no@2x.png 2x, https://cdn.sofifa.net/flags/no@3x.png 3x" class="flag" width="21" height="16"> Norsk</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=hu-HU"><img title="Hungary" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/hu.png" data-srcset="https://cdn.sofifa.net/flags/hu@2x.png 2x, https://cdn.sofifa.net/flags/hu@3x.png 3x" class="flag" width="21" height="16"> Magyar</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=fi-FI"><img title="Finland" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/fi.png" data-srcset="https://cdn.sofifa.net/flags/fi@2x.png 2x, https://cdn.sofifa.net/flags/fi@3x.png 3x" class="flag" width="21" height="16"> Suomi</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=zh-HK"><img title="Hong Kong" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/hk.png" data-srcset="https://cdn.sofifa.net/flags/hk@2x.png 2x, https://cdn.sofifa.net/flags/hk@3x.png 3x" class="flag" width="21" height="16"> 中文(繁體)</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=uk-UA"><img title="Ukraine" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/ua.png" data-srcset="https://cdn.sofifa.net/flags/ua@2x.png 2x, https://cdn.sofifa.net/flags/ua@3x.png 3x" class="flag" width="21" height="16"> Українська</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=cs-CZ"><img title="Czech Republic" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/cz.png" data-srcset="https://cdn.sofifa.net/flags/cz@2x.png 2x, https://cdn.sofifa.net/flags/cz@3x.png 3x" class="flag" width="21" height="16"> Čeština</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=ar-AA"><img title="Saudi Arabia" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/sa.png" data-srcset="https://cdn.sofifa.net/flags/sa@2x.png 2x, https://cdn.sofifa.net/flags/sa@3x.png 3x" class="flag" width="21" height="16"> العربية</a></div>
</div>
<div class="header"><div class="center">
<div role="banner" class="top-banner"><div data-pw-desk="leaderboard_atf" style="width:728px;height:90px" id="pwDeskLbAtf"></div>
<script>
  window.ramp.que.push(function () {
    window.ramp.addTag("pwDeskLbAtf");
  })
</script></div>
<h1 class="ellipsis">팀</h1>
<h2>
<div class="dropdown">
<a rel="nofollow" href="javascript:void(0);" role="button" class="bp3-button bp3-minimal text dropdown-toggle" tabindex="200"><span class="bp3-button-text">FIFA 23</span><span class="bp3-icon bp3-icon-caret-down"><svg viewBox="0 0 24 24" width="16" height="16"><polyline points="6 9 12 15 18 9"></polyline></svg></span></a>
<div class="bp3-menu">
<a class="bp3-menu-item" href="/teams?type=club&r=230052&set=true">FIFA 23</a>
<a class="bp3-menu-item" href="/teams?type=club&r=220069&set=true">FIFA 22</a>
<a class="bp3-menu-item" href="/teams?type=club&r=210064&set=true">FIFA 21</a>
<a class="bp3-menu-item" href="/teams?type=club&r=200061&set=true">FIFA 20</a>
<a class="bp3-menu-item" href="/teams?type=club&r=190075&set=true">FIFA 19</a>
<a class="bp3-menu-item" href="/teams?type=club&r=180084&set=true">FIFA 18</a>
</a>
<a class="bp3-menu-item" href="/teams?type=club&r=202200&set=true">World Cup 2022</a></div>
</div>
</h2>
</div></div>
<div class="sub-nav"><div class="center">
<form action="/teams" method="get" class="top-search bp3-input-group">
<span class="bp3-icon bp3-icon-search"><svg viewBox="0 0 24 24" width="16" height="16"><circle cx="11" cy="11" r="8"></circle><line x1="21" y1="21" x2="16.65" y2="16.65"></line></svg></span>
<input type="text" class="bp3-input suggest" name="keyword" placeholder="검색팀...">
</form><div class="bp3-tabs">
<div class="bp3-tab-list" role="tablist">
<a class="bp3-tab" role="tab" href="/teams">Trending</a>
<a class="bp3-tab" role="tab" aria-selected="true" href="/teams?type=club">소속팀</a>
<a class="bp3-tab" role="tab" href="/teams?type=national">국가대표팀</a>
</div>
</div></div></div>
</header>
<div class="center">
<div class="grid">
<div class="col col-4">
<form action="/teams?type=club&r=230052&set=true" method="get" class="pjax-select pjax-form">
<div class="card">
<h5>열선택</h5>
<div class="choices-column half-spacing"><select name="showCol[]" class="choices-multiple" data-placeholder="Add column" data-always="true" multiple>
<optgroup label="기본"><option value="ti">ID</option><option value="oa" selected>종합</option><option value="at" selected>공격</option><option value="md" selected>미드필드</option><option value="df" selected>수비</option><option value="tb" selected>이적자금</option><option value="cw">클럽 가치</option></optgroup>
<optgroup label="빌드업 플레이"><option value="bs">속도</option><option value="bd">드리블</option><option value="bp">패스</option><option value="bps">위치 선정</option></optgroup>
<optgroup label="기회 창출"><option value="cc">크로스</option><option value="cp">패스</option><option value="cs">슛</option><option value="cps">위치 선정</option></optgroup>
<optgroup label="수비"><option value="da">적극성</option><option value="dm">압박</option><option value="dw">좌우 폭</option><option value="dd">수비수 선</option></optgroup>
<optgroup label="특별한"><option value="dp">국내 명성/인지도</option><option value="ip">국제 명성/인지도</option><option value="ps" selected>선수</option><option value="sa">XI평균연령시작</option><option value="ta">전체팀평균연령</option></optgroup>
</select>
</div>
<div class="bp3-control-group bp3-fill">
<button class="bp3-button bp3-intent-primary" type="submit">적용</button>
<a class="bp3-button pjax" href="/teams?type=club&r=230052&set=true&showCol=reset">초기화</span></a>
</div>
</div>
</form>
<form action="/teams" class="relative pjax-form" data-pjax="content-target">
<div class="card">
<h5>검색</h5>
<div class="half-spacing grid">
<div class="col col-6">
<label class="ellipsis">이름</label>
</div>
<div class="col col-12">
<input type="text" name="keyword" class="bp3-input bp3-fill" value>
</div>
</div>
<input type="hidden" name="type" value="club">
<div class="half-spacing">
<select id="choices-ct" name="ct[]" data-placeholder="대륙" data-value multiple></select></div>
<div class="half-spacing">
<select id="choices-na" name="na[]" data-placeholder="국적" data-value multiple></select></div>
<div class="half-spacing">
<select id="choices-lg" name="lg[]" data-placeholder="리그" data-value multiple></select></div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">종합</label>
</div>
<div class="col col-3">
<input id="oal" type="number" name="oal" placeholder="0" class="bp3-input min" size="2" max="99" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="oah" type="number" name="oah" placeholder="99" class="bp3-input max" size="2" max="99" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">공격</label>
</div>
<div class="col col-3">
<input id="atl" type="number" name="atl" placeholder="0" class="bp3-input min" size="2" max="99" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="ath" type="number" name="ath" placeholder="99" class="bp3-input max" size="2" max="99" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">미드필드</label>
</div>
<div class="col col-3">
<input id="mdl" type="number" name="mdl" placeholder="0" class="bp3-input min" size="2" max="99" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="mdh" type="number" name="mdh" placeholder="99" class="bp3-input max" size="2" max="99" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">수비</label>
</div>
<div class="col col-3">
<input id="dfl" type="number" name="dfl" placeholder="0" class="bp3-input min" size="2" max="99" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="dfh" type="number" name="dfh" placeholder="99" class="bp3-input max" size="2" max="99" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">국제 명성/인지도</label>
</div>
<div class="col col-3">
<input id="ipl" type="number" name="ipl" placeholder="0" class="bp3-input min" size="2" max="20" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="iph" type="number" name="iph" placeholder="20" class="bp3-input max" size="2" max="20" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">국내 명성/인지도</label>
</div>
<div class="col col-3">
<input id="dpl" type="number" name="dpl" placeholder="0" class="bp3-input min" size="2" max="20" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="dph" type="number" name="dph" placeholder="20" class="bp3-input max" size="2" max="20" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">XI평균연령시작</label>
</div>
<div class="col col-3">
<input id="sal" type="number" name="sal" placeholder="15" class="bp3-input min" size="2" max="45" min="15" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="sah" type="number" name="sah" placeholder="45" class="bp3-input max" size="2" max="45" min="15" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">전체팀평균연령</label>
</div>
<div class="col col-3">
<input id="tal" type="number" name="tal" placeholder="15" class="bp3-input min" size="2" max="45" min="15" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="tah" type="number" name="tah" placeholder="45" class="bp3-input max" size="2" max="45" min="15" value>
</div>
</div>
<div>
<button type="submit" class="bp3-button bp3-intent-primary bp3-fill">제출</button>
</div>
</div>
<div class="card">
<h5>수비</h5>
<div class="half-spacing">
<select name="tds[]" data-placeholder="수비 스타일" class="choices-multiple" multiple>
<option value="0">후퇴</option>
<option value="1">밸런스</option>
<option value="2">볼 터치 실수 시 압박</option>
<option value="3">공을 뺏긴 직후 압박</option>
<option value="4">지속적인 압박</option>
</select>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">좌우 폭</label>
</div>
<div class="col col-3">
<input id="tdwl" type="number" name="tdwl" placeholder="0" class="bp3-input min" size="2" max="10" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="tdwh" type="number" name="tdwh" placeholder="10" class="bp3-input max" size="2" max="10" min="0" value>
</div>
</div>
<div class="grid spacing">
<div class="col col-9">
<label class="ellipsis">깊이</label>
</div>
<div class="col col-3">
<input id="tddl" type="number" name="tddl" placeholder="0" class="bp3-input min" size="2" max="10" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="tddh" type="number" name="tddh" placeholder="10" class="bp3-input max" size="2" max="10" min="0" value>
</div>
</div>
<h5>공격</h5>
<div class="half-spacing">
<select name="tbp[]" data-placeholder="빌드업 플레이" class="choices-multiple" multiple>
<option value="0">느린 빌드업</option>
<option value="1">빠른 빌드업</option>
<option value="2">긴 패스</option>
<option value="3">밸런스</option>
<option value="4">점유율</option>
</select>
</div>
<div class="half-spacing">
<select name="tcc[]" data-placeholder="기회 창출" class="choices-multiple" multiple>
<option value="0">점유율</option>
<option value="1">전방 달리기</option>
<option value="2">직접 패스</option>
<option value="3">밸런스</option>
</select>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">폭</label>
</div>
<div class="col col-3">
<input id="towl" type="number" name="towl" placeholder="0" class="bp3-input min" size="2" max="10" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="towh" type="number" name="towh" placeholder="10" class="bp3-input max" size="2" max="10" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">박스 안쪽 선수</label>
</div>
<div class="col col-3">
<input id="tpcl" type="number" name="tpcl" placeholder="0" class="bp3-input min" size="2" max="10" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="tpch" type="number" name="tpch" placeholder="10" class="bp3-input max" size="2" max="10" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">코너킥</label>
</div>
<div class="col col-3">
<input id="tprl" type="number" name="tprl" placeholder="0" class="bp3-input min" size="2" max="5" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="tprh" type="number" name="tprh" placeholder="5" class="bp3-input max" size="2" max="5" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">프리킥</label>
</div>
<div class="col col-3">
<input id="tpfl" type="number" name="tpfl" placeholder="0" class="bp3-input min" size="2" max="5" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="tpfh" type="number" name="tpfh" placeholder="5" class="bp3-input max" size="2" max="5" min="0" value>
</div>
</div>
<div>
<button type="submit" class="bp3-button bp3-intent-primary bp3-fill">제출</button>
</div>
</div>
</form><div class="left-banner double-spacing sticky">
<div data-pw-desk="med_rect_btf" id="pwDeskMedRectBtf1"></div>
<script>
window.ramp.que.push(function () {
window.ramp.addTag("pwDeskMedRectBtf1");
})
</script>
</div>
</div>
<div class="col col-12">
<div class="card">
<table class="table table-hover persist-area">
<thead>
<tr class="persist-header">
<th class="col-avatar"></th>
<th class="col-name-wide text-left">이름</th><th class="tooltip col col-oa" data-tooltip="종합"><a rel="nofollow" class="ellipsis pjax" href="/teams?type=club&r=230052&set=true&col=oa&sort=desc"><span class="bp3-icon sorter"></span>종합 </a></th><th class="tooltip col col-at" data-tooltip="공격"><a rel="nofollow" class="ellipsis pjax" href="/teams?type=club&r=230052&set=true&col
180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/86/rangers/"><div class="ellipsis">Rangers</div></a><a href="/teams?lg=50" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=42" title="Scotland"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/gb-sct.png" data-srcset="https://cdn.sofifa.net/flags/gb-sct@2x.png 2x, https://cdn.sofifa.net/flags/gb-sct@3x.png 3x" class="flag" width="21" height="16"></a> Premiership</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-73">73</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-73">73</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-73">73</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-74">74</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">28</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/3496/60.png" data-srcset="https://cdn.sofifa.net/meta/team/3496/120.png 2x, https://cdn.sofifa.net/meta/team/3496/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/598/sao-paulo/"><div class="ellipsis">São Paulo</div></a><a href="/teams?lg=7" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=54" title="Brazil"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/br.png" data-srcset="https://cdn.sofifa.net/flags/br@2x.png 2x, https://cdn.sofifa.net/flags/br@3x.png 3x" class="flag" width="21" height="16"></a> Serie A</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-73">73</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-72">72</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-73">73</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-73">73</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">20</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/7790/60.png" data-srcset="https://cdn.sofifa.net/meta/team/7790/120.png 2x, https://cdn.sofifa.net/meta/team/7790/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/347/lecce/"><div class="ellipsis">Lecce</div></a><a href="/teams?lg=31" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=27" title="Italy"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/it.png" data-srcset="https://cdn.sofifa.net/flags/it@2x.png 2x, https://cdn.sofifa.net/flags/it@3x.png 3x" class="flag" width="21" height="16"></a> Serie A</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-73">73</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-74">74</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-73">73</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-73">73</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">33</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/57/60.png" data-srcset="https://cdn.sofifa.net/meta/team/57/120.png 2x, https://cdn.sofifa.net/meta/team/57/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/1884/panathinaikos/"><div class="ellipsis">Panathinaikos</div></a><a href="/teams?lg=63" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=22" title="Greece"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/gr.png" data-srcset="https://cdn.sofifa.net/flags/gr@2x.png 2x, https://cdn.sofifa.net/flags/gr@3x.png 3x" class="flag" width="21" height="16"></a> Super League</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-73">73</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-72">72</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-73">73</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-72">72</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">28</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/7011/60.png" data-srcset="https://cdn.sofifa.net/meta/team/7011/120.png 2x, https://cdn.sofifa.net/meta/team/7011/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/605/al-hilal/"><div class="ellipsis">Al Hilal</div></a><a href="/teams?lg=350" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=183" title="Saudi Arabia"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/sa.png" data-srcset="https://cdn.sofifa.net/flags/sa@2x.png 2x, https://cdn.sofifa.net/flags/sa@3x.png 3x" class="flag" width="21" height="16"></a> Pro League</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-73">73</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-74">74</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-75">75</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-71">71</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">30</td></tr></tbody>
</table>
<div class="pagination">
<a href="/teams?type=club&r=230052&set=true&offset=0" class="bp3-button bp3-intent-primary pjax"><span class="bp3-icon bp3-icon-chevron-left"><svg viewBox="0 0 24 24" width="16" height="16"><polyline points="15 18 9 12 15 6"></polyline></svg></span><span class="bp3-button-text">이전</span></a>
<a href="/teams?type=club&r=230052&set=true&offset=120" class="bp3-button bp3-intent-primary pjax"><span class="bp3-button-text">다음</span><span class="bp3-icon bp3-icon-chevron-right"><svg viewBox="0 0 24 24" width="16" height="16"><polyline points="9 18 15 12 9 6"></polyline></svg></span></a>
</div>
</div>
</div>
</div>
</div>
<footer>
<div class="center"><p class="copyright">All product names, logos, and brands are the property of their respective owners.<br>All company, product, and service names used in this website are for identification purposes only.<br><a href="/help/tos">자귀</a>&nbsp;&nbsp;<a href="/help/privacy">은둔</a>&nbsp;&nbsp;<a href="/help/faq">FAQ</a></p></div>
</footer>
<div id="sign-in-form" class="hide"><div class="bp3-dialog-header"><h4 class="bp3-heading">로그인</h4><button type="button" class="bp3-button bp3-minimal bp3-dialog-close-button btn-cancel"><span icon="small-cross" class="bp3-icon bp3-icon-small-cross"><svg viewBox="0 0 24 24" width="20" height="20"><line x1="18" y1="6" x2="6" y2="18"></line><line x1="6" y1="6" x2="18" y2="18"></line></svg></span></button></div><div class="bp3-dialog-body"><form method="post" action="/signIn" class="ajax-form"><div class="bp3-form-group bp3-inline"><input class="bp3-input bp3-fill" type="text" name="email" placeholder="이메일"></div><div class="bp3-form-group bp3-inline"><input class="bp3-input bp3-fill" type="password" name="password" placeholder="암호"></div><div class="bp3-form-group bp3-inline spacing"><div class="bp3-full-width text-right"><a href="/signUp" class="bp3-button bp3-minimal sign-up">가입하기</a><a href="/forgot" class="bp3-button bp3-minimal forgot">비밀번호를잊으셨나요</a>&nbsp;&nbsp;<button type="submit" name="submit" class="bp3-button">로그인</button></div></div><div class="bp3-divider spacing"></div><div class="bp3-form-group bp3-inline"><a class="bp3-button google compact" rel="nofollow" href="/authorize/google" role="tooltip" data-tip-pos="top" aria-label="Google로로그인"><svg xmlns="http://www.w3.org/2000/svg" width="20" height="20" viewBox
.37 262.37 0 0 1-40 19 1.63 1.63 0 0 0-.87 2.28 340.72 340.72 0 0 0 26.13 42.52 1.62 1.62 0 0 0 1.8.61 423.17 423.17 0 0 0 128-64.63 1.64 1.64 0 0 0 .67-1.18c10.68-110.44-17.88-206.38-75.7-291.42a1.3 1.3 0 0 0-.63-.63zM427.09 582.85c-25.23 0-46-23.16-46-51.6s20.38-51.6 46-51.6c25.83 0 46.42 23.36 46 51.6.02 28.44-20.37 51.6-46 51.6zm170.13 0c-25.23 0-46-23.16-46-51.6s20.38-51.6 46-51.6c25.83 0 46.42 23.36 46 51.6.01 28.44-20.17 51.6-46 51.6z" style="fill:#fff" /></svg></a></div></form></div></div>
<div id="sign-up-form" class="hide"><div class="bp3-dialog-header"><h4 class="bp3-heading">가입하기</h4><button type="button" class="bp3-button bp3-minimal bp3-dialog-close-button btn-cancel"><span icon="small-cross" class="bp3-icon bp3-icon-small-cross"><svg viewBox="0 0 24 24" width="20" height="20"><line x1="18" y1="6" x2="6" y2="18"></line><line x1="6" y1="6" x2="18" y2="18"></line></svg></span></button></div><div class="bp3-dialog-body"><form method="post" action="/signUp" data-next="/teams" class="ajax-form"><div class="bp3-form-group bp3-inline"><input class="bp3-input bp3-fill" type="text" name="email" placeholder="이메일"></div><div class="bp3-form-group bp3-inline"><input class="bp3-input bp3-fill" type="text" name="name" placeholder="이름"></div><div class="bp3-form-group bp3-inline"><input class="bp3-input bp3-fill" type="password" name="password" id="password" placeholder="암호"></div><div class="bp3-form-group bp3-inline"><input class="bp3-input bp3-fill" type="password" name="confirmPassword" placeholder="비밀번호확인"></div><div class="bp3-form-group bp3-inline spacing"><div class="bp3-full-width text-right"><button type="submit" name="submit" class="bp3-button">제출</button></div></div></form></div></div>
<div id="forgot-form" class="hide"><div class="bp3-dialog-header"><h4 class="bp3-heading">비밀번호를잊으셨나요</h4><button type="button" class="bp3-button bp3-minimal bp3-dialog-close-button btn-cancel"><span icon="small-cross" class="bp3-icon bp3-icon-small-cross"><svg viewBox="0 0 24 24" width="20" height="20"><line x1="18" y1="6" x2="6" y2="18"></line><line x1="6" y1="6" x2="18" y2="18"></line></svg></span></button></div><div class="bp3-dialog-body"><form method="post" action="/forgot" class="ajax-form"><div class="bp3-form-group bp3-inline">이메일을제공해주세요.추가지침이포함된이메일을보내드리겠습니다.</div><div class="bp3-form-group bp3-inline"><input class="bp3-input bp3-fill" type="text" name="email" placeholder="이메일"></div><div class="bp3-form-group bp3-inline"><div class="bp3-full-width text-right"><button type="submit" name="submit" class="bp3-button">제출</button></div></div></form></div></div>
<script src="https://static.sofifa.net/js/desktop.min.js?20"></script>
<script defer src="https://static.sofifa.net/js/socket.min.js?2"></script>
<script defer src="https://static.sofifa.net/js/uploader.min.js?2"></script>
<script defer src="https://static.sofifa.net/js/comment.min.js?29"></script>
<script async src="https://cdn.intergient.com/1024268/72628/ramp_config.js"></script>
<script async src="https://static.sofifa.net/js/ramp.min.js?2"></script>
<script async src="https://cdn.intergient.com/ramp_core.js"></script>
<script async src="https://www.googletagmanager.com/gtag/js?id=G-X81LWDNFGR"></script>
<script>window.dataLayer = window.dataLayer || [];function gtag(){dataLayer.push(arguments);}gtag('js', new Date());gtag('config', 'G-X81LWDNFGR');</script>
</body>
</html>'''

# %%
html3 = '''

<!DOCTYPE html>
<html lang="ko-KR">
<head id="head">
<title>팀 FIFA 23 2023. 8. 24. SoFIFA</title>
<meta charset="utf-8">
<meta name="viewport" content="width=device-width, initial-scale=1">
<meta name="google-site-verification" content="VGaFvm9Qm-qhCd2LCDi8QKWXNPSrVE2SJ2iT8c3vI1g">
<meta name="description" content="2023. 8. 24. FIFA 23 팀 평점">
<meta name="copyright" content="2009 - 2023 SoFIFA.com">
<meta name="twitter:widgets:theme" content="dark">
<meta name="twitter:widgets:border-color" content="#777777">
<link rel="shortcut icon" href="https://static.sofifa.net/launcher-icon.png">
<link rel="apple-touch-icon" href="https://static.sofifa.net/launcher-icon.png">
<link rel="preconnect" href="https://cdn.intergient.com/" crossorigin>
<link rel="dns-prefetch" href="https://cdn.intergient.com/">
<script>window.ramp = window.ramp || {};window.ramp.que = window.ramp.que || [];</script>
<link rel="alternate" hreflang="en" href="https://sofifa.com/teams?hl=en-US">
<link rel="alternate" hreflang="fr" href="https://sofifa.com/teams?hl=fr-FR">
<link rel="alternate" hreflang="de" href="https://sofifa.com/teams?hl=de-DE">
<link rel="alternate" hreflang="es" href="https://sofifa.com/teams?hl=es-ES">
<link rel="alternate" hreflang="it" href="https://sofifa.com/teams?hl=it-IT">
<link rel="alternate" hreflang="pt-BR" href="https://sofifa.com/teams?hl=pt-BR">
<link rel="alternate" hreflang="nl" href="https://sofifa.com/teams?hl=nl-NL">
<link rel="alternate" hreflang="ko" href="https://sofifa.com/teams?hl=ko-KR">
<link rel="alternate" hreflang="pl" href="https://sofifa.com/teams?hl=pl-PL">
<link rel="alternate" hreflang="zh-CN" href="https://sofifa.com/teams?hl=zh-CN">
<link rel="alternate" hreflang="ru" href="https://sofifa.com/teams?hl=ru-RU">
<link rel="alternate" hreflang="ja" href="https://sofifa.com/teams?hl=ja-JP">
<link rel="alternate" hreflang="sv" href="https://sofifa.com/teams?hl=sv-SE">
<link rel="alternate" hreflang="da" href="https://sofifa.com/teams?hl=da-DK">
<link rel="alternate" hreflang="pt-PT" href="https://sofifa.com/teams?hl=pt-PT">
<link rel="alternate" hreflang="nn" href="https://sofifa.com/teams?hl=nn-NO">
<link rel="alternate" hreflang="hu" href="https://sofifa.com/teams?hl=hu-HU">
<link rel="alternate" hreflang="cs" href="https://sofifa.com/teams?hl=cs-CZ">
<link rel="alternate" hreflang="fi" href="https://sofifa.com/teams?hl=fi-FI">
<link rel="alternate" hreflang="uk" href="https://sofifa.com/teams?hl=uk-UA">
<link rel="alternate" hreflang="tr" href="https://sofifa.com/teams?hl=tr-TR">
<link rel="alternate" hreflang="zh-HK" href="https://sofifa.com/teams?hl=zh-HK">
<link rel="alternate" hreflang="ar" href="https://sofifa.com/teams?hl=ar-AA"><link rel="canonical" href="https://sofifa.com/teams"><link rel="stylesheet" href="https://static.sofifa.net/css/desktop.min.css?39">
<script>let CDN='https://cdn.sofifa.net',CDN_VERSION='20210431',HL='ko-KR',THEME='dark',GENDER=0,IS_MOBILE=false,USER_ID=0,USER_AVATAR='https://cdn.sofifa.net/avatar?name=Guest',BLOCK='블록',UNBLOCK='차단해제',FOLLOW='따르다',UNFOLLOW='팔로우해제',CHOOSE_FILE='파일을선택...',UPLOADING='업로드중...',CHANGE='변화',UPDATED='업데이트',DELETE_CONFIRM='이항목을제거하시겠습니까?',CANCEL='취소',OK='OK',CLOSE='닫기',BLOCK_CONFIRM='이사용자를차단하시겠습니까?<br>나중에\"내관계\"섹션에서설정을변경할수있습니다.',HISTORY_VERSION='역사버전',VERSION='23', ROSTER='230052',FONT=14,LOAD_MORE_COMMENTS='Load more comments',ADD_A_COMMENT='Add a comment',SORT_BY_NEWEST='Sort by newest',SORT_BY_BEST='Sort by best',MY_COMMENTS='My comments',POST='Post',JUST_NOW='just now',COLLAPSE_REPLIES='Collapse replies',COPY_URL='Copy URL',REPORT='신고',UPVOTE='Upvote',DOWNVOTE='Downvote',EDIT='Edit',REPLY='Reply',APPROVE='Approve',REMOVE='없애다',SHOW_FULL_COMMENT='Show full comment',LOAD_IMAGE='Load image',CANCEL_REPLY='Cancel reply',REPLY_TO_THIS_COMMENT='Reply to this comment',CANCEL_EDIT='Cancel edit',EDIT_THIS_COMMENT='Edit this comment',EXPAND_REPLIES='Expand replies',PLEASE_CHOOSE_A_REASON='Please choose a reason',RACISM='Racism',INSULT='Insult',SPAMMING='Spamming',PORN='Porn',PRIVATE_INFO='Private info',OTHER='기타',DESCRIPTION_OPTIONAL='Description (optional)',SAVING='Saving ...',OPERATION_SUCCEED='작업성공',TYPE_TO_SEARCH='검색할유형',AI_MODERATION=1;</script>
</head>
<body class="is-preload  dark" data-class="is-preload  dark" lang="ko-KR" id="body">
<header>
<nav class="bp3-navbar">
<div class="center">
<div class="bp3-navbar-group bp3-align-left reset">
<div class="bp3-navbar-heading">
<a href="/" rel="nofollow"><img alt="SoFIFA" src="https://cdn.sofifa.net/images/launcher-icon.png" width="30" height="30"></a>
</div>
<a href="/players" class="bp3-button bp3-minimal">선수</a>
<a href="/teams" class="bp3-button bp3-minimal">팀</a>
<a href="/squads" class="bp3-button bp3-minimal">분대</a>
<a href="/shortlists" class="bp3-button bp3-minimal">명단</a>
<a rel="nofollow" href="/discussion/1" class="bp3-button bp3-minimal">토론</a>
</div>
<div class="bp3-navbar-group bp3-align-right">
<a rel="nofollow" href="/signIn" role="button" class="bp3-button bp3-minimal need-sign-in" tabindex="101">로그인</a>
<div class="dropdown dropdown-right">
<a rel="nofollow" href="javascript:void(0);" role="button" class="bp3-button bp3-minimal block dropdown-toggle" tabindex="102" title="설정"><span class="bp3-icon"><svg viewBox="0 0 24 24" width="18" height="18"><circle cx="12" cy="12" r="3"></circle><path d="M19.4 15a1.65 1.65 0 0 0 .33 1.82l.06.06a2 2 0 0 1 0 2.83 2 2 0 0 1-2.83 0l-.06-.06a1.65 1.65 0 0 0-1.82-.33 1.65 1.65 0 0 0-1 1.51V21a2 2 0 0 1-2 2 2 2 0 0 1-2-2v-.09A1.65 1.65 0 0 0 9 19.4a1.65 1.65 0 0 0-1.82.33l-.06.06a2 2 0 0 1-2.83 0 2 2 0 0 1 0-2.83l.06-.06a1.65 1.65 0 0 0 .33-1.82 1.65 1.65 0 0 0-1.51-1H3a2 2 0 0 1-2-2 2 2 0 0 1 2-2h.09A1.65 1.65 0 0 0 4.6 9a1.65 1.65 0 0 0-.33-1.82l-.06-.06a2 2 0 0 1 0-2.83 2 2 0 0 1 2.83 0l.06.06a1.65 1.65 0 0 0 1.82.33H9a1.65 1.65 0 0 0 1-1.51V3a2 2 0 0 1 2-2 2 2 0 0 1 2 2v.09a1.65 1.65 0 0 0 1 1.51 1.65 1.65 0 0 0 1.82-.33l.06-.06a2 2 0 0 1 2.83 0 2 2 0 0 1 0 2.83l-.06.06a1.65 1.65 0 0 0-.33 1.82V9a1.65 1.65 0 0 0 1.51 1H21a2 2 0 0 1 2 2 2 2 0 0 1-2 2h-.09a1.65 1.65 0 0 0-1.51 1z"></path></svg></span></a>
<div class="bp3-menu">
<div class="bp3-menu-header">성별</div>
<a class="bp3-menu-item bp3-active" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&gender=0">Men</a>
<a class="bp3-menu-item" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&gender=1">Women</a>
<div class="bp3-menu-header">단위</div>
<a class="bp3-menu-item" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&units=imperial">피트인치/파운드</a>
<a class="bp3-menu-item bp3-active" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&units=mks">cm / kg</a>
<div class="bp3-menu-header">통화</div>
<a class="bp3-menu-item bp3-active" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&currency=EUR">€ EUR</a>
<a class="bp3-menu-item" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&currency=USD">$ USD</a>
<a class="bp3-menu-item" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&currency=GBP">£ GBP</a>
<div class="bp3-menu-header">컬러스키마</div>
<a class="bp3-menu-item bp3-active" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&engine=frostbite">동상</a>
<a class="bp3-menu-item" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&engine=ignite">Ignite</a>
<a class="bp3-menu-item" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&engine=impact">Impact</a>
<div class="bp3-menu-header">잠재력</div>
<a class="bp3-menu-item bp3-active" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&potential=show">보기</a>
<a class="bp3-menu-item" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&potential=hide">숨기기</a>
</div>
</div>
<label class="bp3-button bp3-minimal block" for="theme">
<input id="theme" name="theme" value="light" type="checkbox" class="hide">
<span class="bp3-icon"><svg viewBox="0 0 24 24" width="18" height="18"><path d="M12 18q2.484 0 4.242-1.758t1.758-4.242-1.758-4.242-4.242-1.758q-1.219 0-2.484 0.563 1.547 0.703 2.508 2.18t0.961 3.258-0.961 3.258-2.508 2.18q1.266 0.563 2.484 0.563zM20.016 8.672l3.281 3.328-3.281 3.328v4.688h-4.688l-3.328 3.281-3.328-3.281h-4.688v-4.688l-3.281-3.328 3.281-3.328v-4.688h4.688l3.328-3.281 3.328 3.281h4.688v4.688z"></path></svg></span>
</label>
<a rel="nofollow" href="javascript:void(0);" role="button" class="bp3-button bp3-minimal lang-toggle" tabindex="104"><img title="Korea Republic" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/kr.png" data-srcset="https://cdn.sofifa.net/flags/kr@2x.png 2x, https://cdn.sofifa.net/flags/kr@3x.png 3x" class="flag" width="21" height="16"> <span class="bp3-icon"><svg viewBox="0 0 24 24" width="16" height="16"><polyline points="6 9 12 15 18 9"></polyline></svg></span></a>
</div>
</div>
</nav>
<div id="lang" class="header hide">
<div class="center">
<a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=en-US"><img title="United States" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/us.png" data-srcset="https://cdn.sofifa.net/flags/us@2x.png 2x, https://cdn.sofifa.net/flags/us@3x.png 3x" class="flag" width="21" height="16"> English</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=de-DE"><img title="Germany" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/de.png" data-srcset="https://cdn.sofifa.net/flags/de@2x.png 2x, https://cdn.sofifa.net/flags/de@3x.png 3x" class="flag" width="21" height="16"> Deutsch</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=pt-BR"><img title="Brazil" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/br.png" data-srcset="https://cdn.sofifa.net/flags/br@2x.png 2x, https://cdn.sofifa.net/flags/br@3x.png 3x" class="flag" width="21" height="16"> Português Brasileiro</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=fr-FR"><img title="France" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/fr.png" data-srcset="https://cdn.sofifa.net/flags/fr@2x.png 2x, https://cdn.sofifa.net/flags/fr@3x.png 3x" class="flag" width="21" height="16"> Français</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=es-ES"><img title="Spain" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/es.png" data-srcset="https://cdn.sofifa.net/flags/es@2x.png 2x, https://cdn.sofifa.net/flags/es@3x.png 3x" class="flag" width="21" height="16"> Español</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=it-IT"><img title="Italy" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/it.png" data-srcset="https://cdn.sofifa.net/flags/it@2x.png 2x, https://cdn.sofifa.net/flags/it@3x.png 3x" class="flag" width="21" height="16"> Italiano</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=nl-NL"><img title="Netherlands" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/nl.png" data-srcset="https://cdn.sofifa.net/flags/nl@2x.png 2x, https://cdn.sofifa.net/flags/nl@3x.png 3x" class="flag" width="21" height="16"> Dutch</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=ja-JP"><img title="Japan" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/jp.png" data-srcset="https://cdn.sofifa.net/flags/jp@2x.png 2x, https://cdn.sofifa.net/flags/jp@3x.png 3x" class="flag" width="21" height="16"> 日本語</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=pl-PL"><img title="Poland" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/pl.png" data-srcset="https://cdn.sofifa.net/flags/pl@2x.png 2x, https://cdn.sofifa.net/flags/pl@3x.png 3x" class="flag" width="21" height="16"> Polski</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=tr-TR"><img title="Turkey" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/tr.png" data-srcset="https://cdn.sofifa.net/flags/tr@2x.png 2x, https://cdn.sofifa.net/flags/tr@3x.png 3x" class="flag" width="21" height="16"> Türkçe</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=zh-CN"><img title="China PR" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/cn.png" data-srcset="https://cdn.sofifa.net/flags/cn@2x.png 2x, https://cdn.sofifa.net/flags/cn@3x.png 3x" class="flag" width="21" height="16"> 中文(简体)</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=sv-SE"><img title="Sweden" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/se.png" data-srcset="https://cdn.sofifa.net/flags/se@2x.png 2x, https://cdn.sofifa.net/flags/se@3x.png 3x" class="flag" width="21" height="16"> Svenska</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=ru-RU"><img title="Russia" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/ru.png" data-srcset="https://cdn.sofifa.net/flags/ru@2x.png 2x, https://cdn.sofifa.net/flags/ru@3x.png 3x" class="flag" width="21" height="16"> Русский</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=pt-PT"><img title="Portugal" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/pt.png" data-srcset="https://cdn.sofifa.net/flags/pt@2x.png 2x, https://cdn.sofifa.net/flags/pt@3x.png 3x" class="flag" width="21" height="16"> Português</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=ko-KR"><img title="Korea Republic" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/kr.png" data-srcset="https://cdn.sofifa.net/flags/kr@2x.png 2x, https://cdn.sofifa.net/flags/kr@3x.png 3x" class="flag" width="21" height="16"> 한국어</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=da-DK"><img title="Denmark" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/dk.png" data-srcset="https://cdn.sofifa.net/flags/dk@2x.png 2x, https://cdn.sofifa.net/flags/dk@3x.png 3x" class="flag" width="21" height="16"> Dansk</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=nn-NO"><img title="Norway" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/no.png" data-srcset="https://cdn.sofifa.net/flags/no@2x.png 2x, https://cdn.sofifa.net/flags/no@3x.png 3x" class="flag" width="21" height="16"> Norsk</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=hu-HU"><img title="Hungary" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/hu.png" data-srcset="https://cdn.sofifa.net/flags/hu@2x.png 2x, https://cdn.sofifa.net/flags/hu@3x.png 3x" class="flag" width="21" height="16"> Magyar</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=fi-FI"><img title="Finland" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/fi.png" data-srcset="https://cdn.sofifa.net/flags/fi@2x.png 2x, https://cdn.sofifa.net/flags/fi@3x.png 3x" class="flag" width="21" height="16"> Suomi</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=zh-HK"><img title="Hong Kong" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/hk.png" data-srcset="https://cdn.sofifa.net/flags/hk@2x.png 2x, https://cdn.sofifa.net/flags/hk@3x.png 3x" class="flag" width="21" height="16"> 中文(繁體)</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=uk-UA"><img title="Ukraine" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/ua.png" data-srcset="https://cdn.sofifa.net/flags/ua@2x.png 2x, https://cdn.sofifa.net/flags/ua@3x.png 3x" class="flag" width="21" height="16"> Українська</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=cs-CZ"><img title="Czech Republic" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/cz.png" data-srcset="https://cdn.sofifa.net/flags/cz@2x.png 2x, https://cdn.sofifa.net/flags/cz@3x.png 3x" class="flag" width="21" height="16"> Čeština</a><a class="bp3-button bp3-minimal lang" role="button" rel="nofollow" href="/teams?type=club&r=230052&set=true&hl=ar-AA"><img title="Saudi Arabia" alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/sa.png" data-srcset="https://cdn.sofifa.net/flags/sa@2x.png 2x, https://cdn.sofifa.net/flags/sa@3x.png 3x" class="flag" width="21" height="16"> العربية</a></div>
</div>
<div class="header"><div class="center">
<div role="banner" class="top-banner"><div data-pw-desk="leaderboard_atf" style="width:728px;height:90px" id="pwDeskLbAtf"></div>
<script>
  window.ramp.que.push(function () {
    window.ramp.addTag("pwDeskLbAtf");
  })
</script></div>
<h1 class="ellipsis">팀</h1>
<h2>
<div class="dropdown">
<a rel="nofollow" href="javascript:void(0);" role="button" class="bp3-button bp3-minimal text dropdown-toggle" tabindex="200"><span class="bp3-button-text">FIFA 23</span><span class="bp3-icon bp3-icon-caret-down"><svg viewBox="0 0 24 24" width="16" height="16"><polyline points="6 9 12 15 18 9"></polyline></svg></span></a>
<div class="bp3-menu">
<a class="bp3-menu-item" href="/teams?type=club&r=230052&set=true">FIFA 23</a>
<a class="bp3-menu-item" href="/teams?type=club&r=220069&set=true">FIFA 22</a>
<a class="bp3-menu-item" href="/teams?type=club&r=210064&set=true">FIFA 21</a>
<a class="bp3-menu-item" href="/teams?type=club&r=200061&set=true">FIFA 20</a>
<a class="bp3-menu-item" href="/teams?type=club&r=190075&set=true">FIFA 19</a>
<a class="bp3-menu-item" href="/teams?type=club&r=180084&set=true">FIFA 18</a>
<a class="bp3-menu-item" href="/teams?type=club&r=170099&set=true">FIFA 17</a>
<a class="bp3-menu-item" href="/teams?type=club&r=160058&set=true">FIFA 16</a>
<a class="bp3-menu-item" href="/teams?type=club&r=150059&set=true">FIFA 15</a>
<input type="text" class="bp3-input suggest" name="keyword" placeholder="검색팀...">
</form><div class="bp3-tabs">
<div class="bp3-tab-list" role="tablist">
<a class="bp3-tab" role="tab" href="/teams">Trending</a>
<a class="bp3-tab" role="tab" aria-selected="true" href="/teams?type=club">소속팀</a>
<a class="bp3-tab" role="tab" href="/teams?type=national">국가대표팀</a>
</div>
</div></div></div>
</header>
<div class="center">
<div class="grid">
<div class="col col-4">
<form action="/teams?type=club&r=230052&set=true" method="get" class="pjax-select pjax-form">
<div class="card">
<h5>열선택</h5>
<div class="choices-column half-spacing"><select name="showCol[]" class="choices-multiple" data-placeholder="Add column" data-always="true" multiple>
<optgroup label="기본"><option value="ti">ID</option><option value="oa" selected>종합</option><option value="at" selected>공격</option><option value="md" selected>미드필드</option><option value="df" selected>수비</option><option value="tb" selected>이적자금</option><option value="cw">클럽 가치</option></optgroup>
<optgroup label="빌드업 플레이"><option value="bs">속도</option><option value="bd">드리블</option><option value="bp">패스</option><option value="bps">위치 선정</option></optgroup>
<optgroup label="기회 창출"><option value="cc">크로스</option><option value="cp">패스</option><option value="cs">슛</option><option value="cps">위치 선정</option></optgroup>
<optgroup label="수비"><option value="da">적극성</option><option value="dm">압박</option><option value="dw">좌우 폭</option><option value="dd">수비수 선</option></optgroup>
<optgroup label="특별한"><option value="dp">국내 명성/인지도</option><option value="ip">국제 명성/인지도</option><option value="ps" selected>선수</option><option value="sa">XI평균연령시작</option><option value="ta">전체팀평균연령</option></optgroup>
</select>
</div>
<div class="bp3-control-group bp3-fill">
<button class="bp3-button bp3-intent-primary" type="submit">적용</button>
<a class="bp3-button pjax" href="/teams?type=club&r=230052&set=true&showCol=reset">초기화</span></a>
</div>
</div>
</form>
<form action="/teams" class="relative pjax-form" data-pjax="content-target">
<div class="card">
<h5>검색</h5>
<div class="half-spacing grid">
<div class="col col-6">
<label class="ellipsis">이름</label>
</div>
<div class="col col-12">
<input type="text" name="keyword" class="bp3-input bp3-fill" value>
</div>
</div>
<input type="hidden" name="type" value="club">
<div class="half-spacing">
<select id="choices-ct" name="ct[]" data-placeholder="대륙" data-value multiple></select></div>
<div class="half-spacing">
<select id="choices-na" name="na[]" data-placeholder="국적" data-value multiple></select></div>
<div class="half-spacing">
<select id="choices-lg" name="lg[]" data-placeholder="리그" data-value multiple></select></div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">종합</label>
</div>
<div class="col col-3">
<input id="oal" type="number" name="oal" placeholder="0" class="bp3-input min" size="2" max="99" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="oah" type="number" name="oah" placeholder="99" class="bp3-input max" size="2" max="99" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">공격</label>
</div>
<div class="col col-3">
<input id="atl" type="number" name="atl" placeholder="0" class="bp3-input min" size="2" max="99" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="ath" type="number" name="ath" placeholder="99" class="bp3-input max" size="2" max="99" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">미드필드</label>
</div>
<div class="col col-3">
<input id="mdl" type="number" name="mdl" placeholder="0" class="bp3-input min" size="2" max="99" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="mdh" type="number" name="mdh" placeholder="99" class="bp3-input max" size="2" max="99" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">수비</label>
</div>
<div class="col col-3">
<input id="dfl" type="number" name="dfl" placeholder="0" class="bp3-input min" size="2" max="99" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="dfh" type="number" name="dfh" placeholder="99" class="bp3-input max" size="2" max="99" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">국제 명성/인지도</label>
</div>
<div class="col col-3">
<input id="ipl" type="number" name="ipl" placeholder="0" class="bp3-input min" size="2" max="20" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="iph" type="number" name="iph" placeholder="20" class="bp3-input max" size="2" max="20" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">국내 명성/인지도</label>
</div>
<div class="col col-3">
<input id="dpl" type="number" name="dpl" placeholder="0" class="bp3-input min" size="2" max="20" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="dph" type="number" name="dph" placeholder="20" class="bp3-input max" size="2" max="20" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">XI평균연령시작</label>
</div>
<div class="col col-3">
<input id="sal" type="number" name="sal" placeholder="15" class="bp3-input min" size="2" max="45" min="15" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="sah" type="number" name="sah" placeholder="45" class="bp3-input max" size="2" max="45" min="15" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">전체팀평균연령</label>
</div>
<div class="col col-3">
<input id="tal" type="number" name="tal" placeholder="15" class="bp3-input min" size="2" max="45" min="15" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="tah" type="number" name="tah" placeholder="45" class="bp3-input max" size="2" max="45" min="15" value>
</div>
</div>
<div>
<button type="submit" class="bp3-button bp3-intent-primary bp3-fill">제출</button>
</div>
</div>
<div class="card">
<h5>수비</h5>
<div class="half-spacing">
<select name="tds[]" data-placeholder="수비 스타일" class="choices-multiple" multiple>
<option value="0">후퇴</option>
<option value="1">밸런스</option>
<option value="2">볼 터치 실수 시 압박</option>
<option value="3">공을 뺏긴 직후 압박</option>
<option value="4">지속적인 압박</option>
</select>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">좌우 폭</label>
</div>
<div class="col col-3">
<input id="tdwl" type="number" name="tdwl" placeholder="0" class="bp3-input min" size="2" max="10" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="tdwh" type="number" name="tdwh" placeholder="10" class="bp3-input max" size="2" max="10" min="0" value>
</div>
</div>
<div class="grid spacing">
<div class="col col-9">
<label class="ellipsis">깊이</label>
</div>
<div class="col col-3">
<input id="tddl" type="number" name="tddl" placeholder="0" class="bp3-input min" size="2" max="10" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="tddh" type="number" name="tddh" placeholder="10" class="bp3-input max" size="2" max="10" min="0" value>
</div>
</div>
<h5>공격</h5>
<div class="half-spacing">
<select name="tbp[]" data-placeholder="빌드업 플레이" class="choices-multiple" multiple>
<option value="0">느린 빌드업</option>
<option value="1">빠른 빌드업</option>
<option value="2">긴 패스</option>
<option value="3">밸런스</option>
<option value="4">점유율</option>
</select>
</div>
<div class="half-spacing">
<select name="tcc[]" data-placeholder="기회 창출" class="choices-multiple" multiple>
<option value="0">점유율</option>
<option value="1">전방 달리기</option>
<option value="2">직접 패스</option>
<option value="3">밸런스</option>
</select>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">폭</label>
</div>
<div class="col col-3">
<input id="towl" type="number" name="towl" placeholder="0" class="bp3-input min" size="2" max="10" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="towh" type="number" name="towh" placeholder="10" class="bp3-input max" size="2" max="10" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">박스 안쪽 선수</label>
</div>
<div class="col col-3">
<input id="tpcl" type="number" name="tpcl" placeholder="0" class="bp3-input min" size="2" max="10" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="tpch" type="number" name="tpch" placeholder="10" class="bp3-input max" size="2" max="10" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">코너킥</label>
</div>
<div class="col col-3">
<input id="tprl" type="number" name="tprl" placeholder="0" class="bp3-input min" size="2" max="5" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="tprh" type="number" name="tprh" placeholder="5" class="bp3-input max" size="2" max="5" min="0" value>
</div>
</div>
<div class="grid half-spacing">
<div class="col col-9">
<label class="ellipsis">프리킥</label>
</div>
<div class="col col-3">
<input id="tpfl" type="number" name="tpfl" placeholder="0" class="bp3-input min" size="2" max="5" min="0" value>
</div>
<div class="col col-1"></div>
<div class="col col-3">
<input id="tpfh" type="number" name="tpfh" placeholder="5" class="bp3-input max" size="2" max="5" min="0" value>
</div>
</div>
<div>
<button type="submit" class="bp3-button bp3-intent-primary bp3-fill">제출</button>
</div>
</div>
</form><div class="left-banner double-spacing sticky">
<div data-pw-desk="med_rect_btf" id="pwDeskMedRectBtf1"></div>
<script>
window.ramp.que.push(function () {
window.ramp.addTag("pwDeskMedRectBtf1");
})
</script>
</div>
</div>
<div class="col col-12">
<div class="card">
<table class="table table-hover persist-area">
<thead>
<tr class="persist-header">
<th class="col-avatar"></th>
<th class="col-name-wide text-left">이름</th><th class="tooltip col col-oa" data-tooltip="종합"><a rel="nofollow" class="ellipsis pjax" href="/teams?type=club&r=230052&set=true&col=oa&sort=desc"><span class="bp3-icon sorter"></span>종합 </a></th><th class="tooltip col col-at" data-tooltip="공격"><a rel="nofollow" class="ellipsis pjax" href="/teams?type=club&r=230052&set=true&col=at&sort=desc"><span class="bp3-icon sorter"></span>공격 </a></th><th class="tooltip col col-md" data-tooltip="미드필드"><a rel="nofollow" class="ellipsis pjax" href="/teams?type=club&r=230052&set=true&col=md&sort=desc"><span class="bp3-icon sorter"></span>미드필드 </a></th><th class="tooltip col col-df" data-tooltip="수비"><a rel="nofollow" class="ellipsis pjax" href="/teams?type=club&r=230052&set=true&col=df&sort=desc"><span class="bp3-icon sorter"></span>수비 </a></th><th class="tooltip col col-tb" data-tooltip="이적자금"><a rel="nofollow" class="ellipsis pjax" href="/teams?type=club&r=230052&set=true&col=tb&sort=desc"><span class="bp3-icon sorter"></span>이적자금 </a></th><th class="tooltip col col-ps" data-tooltip="선수"><a rel="nofollow" class="ellipsis pjax" href="/teams?type=club&r=230052&set=true&col=ps&sort=desc"><span class="bp3-icon sorter"></span>선수 </a></th></tr>
</thead>
<tbody><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/266/60.png" data-srcset="https://cdn.sofifa.net/meta/team/266/120.png 2x, https://cdn.sofifa.net/meta/team/266/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/378/brest/"><div class="ellipsis">Brest</div></a><a href="/teams?lg=16" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=18" title="France"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/fr.png" data-srcset="https://cdn.sofifa.net/flags/fr@2x.png 2x, https://cdn.sofifa.net/flags/fr@3x.png 3x" class="flag" width="21" height="16"></a> Ligue 1</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-73">73</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-73">73</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-73">73</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-72">72</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">26</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/1028/60.png" data-srcset="https://cdn.sofifa.net/meta/team/1028/120.png 2x, https://cdn.sofifa.net/meta/team/1028/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/379/stade-de-reims/"><div class="ellipsis">Stade de Reims </div></a><a href="/teams?lg=16" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=18" title="France"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/fr.png" data-srcset="https://cdn.sofifa.net/flags/fr@2x.png 2x, https://cdn.sofifa.net/flags/fr@3x.png 3x" class="flag" width="21" height="16"></a> Ligue 1</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-73">73</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-76">76</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-73">73</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-74">74</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">24</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/3545/60.png" data-srcset="https://cdn.sofifa.net/meta/team/3545/120.png 2x, https://cdn.sofifa.net/meta/team/3545/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/110468/viktoria-plzen/"><div class="ellipsis">Viktoria Plzeň</div></a><a href="/teams?lg=319" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=12" title="Czech Republic"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/cz.png" data-srcset="https://cdn.sofifa.net/flags/cz@2x.png 2x, https://cdn.sofifa.net/flags/cz@3x.png 3x" class="flag" width="21" height="16"></a> Fortuna Liga</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-73">73</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-73">73</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-73">73</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-72">72</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">24</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/649/60.png" data-srcset="https://cdn.sofifa.net/meta/team/649/120.png 2x, https://cdn.sofifa.net/meta/team/649/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/393/paok/"><div class="ellipsis">PAOK</div></a><a href="/teams?lg=63" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=22" title="Greece"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/gr.png" data-srcset="https://cdn.sofifa.net/flags/gr@2x.png 2x, https://cdn.sofifa.net/flags/gr@3x.png 3x" class="flag" width="21" height="16"></a> Super League</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-73">73</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-73">73</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-73">73</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-71">71</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">28</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/345/60.png" data-srcset="https://cdn.sofifa.net/meta/team/345/120.png 2x, https://cdn.sofifa.net/meta/team/345/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/110741/spezia/"><div class="ellipsis">Spezia</div></a><a href="/teams?lg=31" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=27" title="Italy"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/it.png" data-srcset="https://cdn.sofifa.net/flags/it@2x.png 2x, https://cdn.sofifa.net/flags/it@3x.png 3x" class="flag" width="21" height="16"></a> Serie A</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-73">73</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-75">75</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-71">71</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-71">71</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">28</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/999/60.png" data-srcset="https://cdn.sofifa.net/meta/team/999/120.png 2x, https://cdn.sofifa.net/meta/team/999/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/160/vfl-bochum-1848/"><div class="ellipsis">VfL Bochum 1848</div></a><a href="/teams?lg=19" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=21" title="Germany"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/de.png" data-srcset="https://cdn.sofifa.net/flags/de@2x.png 2x, https://cdn.sofifa.net/flags/de@3x.png 3x" class="flag" width="21" height="16"></a> Bundesliga</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-73">73</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-73">73</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-72">72</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-73">73</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">29</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/2709/60.png" data-srcset="https://cdn.sofifa.net/meta/team/2709/120.png 2x, https://cdn.sofifa.net/meta/team/2709/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/673/genk/"><div class="ellipsis">Genk</div></a><a href="/teams?lg=4" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=7" title="Belgium"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/be.png" data-srcset="https://cdn.sofifa.net/flags/be@2x.png 2x, https://cdn.sofifa.net/flags/be@3x.png 3x" class="flag" width="21" height="16"></a> Jupiler Pro League</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-73">73</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-72">72</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-74">74</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-72">72</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">28</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/2921/60.png" data-srcset="https://cdn.sofifa.net/meta/team/2921/120.png 2x, https://cdn.sofifa.net/meta/team/2921/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/472/las-palmas/"><div class="ellipsis">Las Palmas</div></a><a href="/teams?lg=54" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=45" title="Spain"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/es.png" data-srcset="https://cdn.sofifa.net/flags/es@2x.png 2x, https://cdn.sofifa.net/flags/es@3x.png 3x" class="flag" width="21" height="16"></a> La Liga 2</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-73">73</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-73">73</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-74">74</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-73">73</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">30</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team
div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-71">71</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-71">71</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-71">71</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-71">71</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">20</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/2975/60.png" data-srcset="https://cdn.sofifa.net/meta/team/2975/120.png 2x, https://cdn.sofifa.net/meta/team/2975/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/463/deportivo-alaves/"><div class="ellipsis">Deportivo Alavés</div></a><a href="/teams?lg=54" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=45" title="Spain"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/es.png" data-srcset="https://cdn.sofifa.net/flags/es@2x.png 2x, https://cdn.sofifa.net/flags/es@3x.png 3x" class="flag" width="21" height="16"></a> La Liga 2</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-71">71</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-71">71</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-72">72</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-71">71</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">30</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/60/60.png" data-srcset="https://cdn.sofifa.net/meta/team/60/120.png 2x, https://cdn.sofifa.net/meta/team/60/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/467/sd-eibar/"><div class="ellipsis">SD Eibar</div></a><a href="/teams?lg=54" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=45" title="Spain"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/es.png" data-srcset="https://cdn.sofifa.net/flags/es@2x.png 2x, https://cdn.sofifa.net/flags/es@3x.png 3x" class="flag" width="21" height="16"></a> La Liga 2</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-71">71</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-70">70</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-71">71</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-71">71</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">29</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/9335/60.png" data-srcset="https://cdn.sofifa.net/meta/team/9335/120.png 2x, https://cdn.sofifa.net/meta/team/9335/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/101083/estudiantes/"><div class="ellipsis">Estudiantes</div></a><a href="/teams?lg=353" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=52" title="Argentina"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/ar.png" data-srcset="https://cdn.sofifa.net/flags/ar@2x.png 2x, https://cdn.sofifa.net/flags/ar@3x.png 3x" class="flag" width="21" height="16"></a> Liga Profesional</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-71">71</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-72">72</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-73">73</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-70">70</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">27</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/102/60.png" data-srcset="https://cdn.sofifa.net/meta/team/102/120.png 2x, https://cdn.sofifa.net/meta/team/102/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/110556/genoa/"><div class="ellipsis">Genoa</div></a><a href="/teams?lg=32" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=27" title="Italy"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/it.png" data-srcset="https://cdn.sofifa.net/flags/it@2x.png 2x, https://cdn.sofifa.net/flags/it@3x.png 3x" class="flag" width="21" height="16"></a> Serie B</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-71">71</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-74">74</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-71">71</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-70">70</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">28</td></tr><tr>
<td class="col-avatar">
<figure class="avatar">
<img alt class="team" data-src="https://cdn.sofifa.net/meta/team/828/60.png" data-srcset="https://cdn.sofifa.net/meta/team/828/120.png 2x, https://cdn.sofifa.net/meta/team/828/180.png 3x" src="https://cdn.sofifa.net/empty.svg" data-root="https://cdn.sofifa.net/" data-type="team">
</figure>
</td>
<td class="col-name-wide">
<a href="/team/111325/nacional/"><div class="ellipsis">Nacional</div></a><a href="/teams?lg=338" rel="nofollow" class="sub"><div class="ellipsis"><a rel="nofollow" href="/players?na=60" title="Uruguay"><img alt src="https://cdn.sofifa.net/pixel.gif" data-src="https://cdn.sofifa.net/flags/uy.png" data-srcset="https://cdn.sofifa.net/flags/uy@2x.png 2x, https://cdn.sofifa.net/flags/uy@3x.png 3x" class="flag" width="21" height="16"></a> Primera Division</div></a></td>
<td class="col col-oa" data-col="oa"><span class="bp3-tag p p-71">71</span></td><td class="col col-at" data-col="at"><span class="bp3-tag p p-71">71</span></td><td class="col col-md" data-col="md"><span class="bp3-tag p p-70">70</span></td><td class="col col-df" data-col="df"><span class="bp3-tag p p-70">70</span></td><td class="col col-tb" data-col="tb">€0</td><td class="col col-ps" data-col="ps">28</td></tr></tbody>
</table>
<div class="pagination">
<a href="/teams?type=club&r=230052&set=true&offset=60" class="bp3-button bp3-intent-primary pjax"><span class="bp3-icon bp3-icon-chevron-left"><svg viewBox="0 0 24 24" width="16" height="16"><polyline points="15 18 9 12 15 6"></polyline></svg></span><span class="bp3-button-text">이전</span></a>
<a href="/teams?type=club&r=230052&set=true&offset=180" class="bp3-button bp3-intent-primary pjax"><span class="bp3-button-text">다음</span><span class="bp3-icon bp3-icon-chevron-right"><svg viewBox="0 0 24 24" width="16" height="16"><polyline points="9 18 15 12 9 6"></polyline></svg></span></a>
</div>
</div>
</div>
</div>
</div>
<footer>
<div class="center"><p class="copyright">All product names, logos, and brands are the property of their respective owners.<br>All company, product, and service names used in this website are for identification purposes only.<br><a href="/help/tos">자귀</a>&nbsp;&nbsp;<a href="/help/privacy">은둔</a>&nbsp;&nbsp;<a href="/help/faq">FAQ</a></p></div>
</footer>
<div id="sign-in-form" class="hide"><div class="bp3-dialog-header"><h4 class="bp3-heading">로그인</h4><button type="button" class="bp3-button bp3-minimal bp3-dialog-close-button btn-cancel"><span icon="small-cross" class="bp3-icon bp3-icon-small-cross"><svg viewBox="0 0 24 24" width="20" height="20"><line x1="18" y1="6" x2="6" y2="18"></line><line x1="6" y1="6" x2="18" y2="18"></line></svg></span></button></div><div class="bp3-dialog-body"><form method="post" action="/signIn" class="ajax-form"><div class="bp3-form-group bp3-inline"><input class="bp3-input bp3-fill" type="text" name="email" placeholder="이메일"></div><div class="bp3-form-group bp3-inline"><input class="bp3-input bp3-fill" type="password" name="password" placeholder="암호"></div><div class="bp3-form-group bp3-inline spacing"><div class="bp3-full-width text-right"><a href="/signUp" class="bp3-button bp3-minimal sign-up">가입하기</a><a href="/forgot" class="bp3-button bp3-minimal forgot">비밀번호를잊으셨나요</a>&nbsp;&nbsp;<button type="submit" name="submit" class="bp3-button">로그인</button></div></div><div class="bp3-divider spacing"></div><div class="bp3-form-group bp3-inline"><a class="bp3-button google compact" rel="nofollow" href="/authorize/google" role="tooltip" data-tip-pos="top" aria-label="Google로로그인"><svg xmlns="http://www.w3.org/2000/svg" width="20" height="20" viewBox="0 0 186.69 190.5"><g transform="translate(1184.583 765.171)"><path clip-path="none" mask="none" d="M-1089.333-687.239v36.888h51.262c-2.251 11.863-9.006 21.908-19.137 28.662l30.913 23.986c18.011-16.625 28.402-41.044 28.402-70.052 0-6.754-.606-13.249-1.732-19.483z" fill="#4285f4" /><path clip-path="none" mask="none" d="M-1142.714-651.791l-6.972 5.337-24.679 19.223h0c15.673 31.086 47.796 52.561 85.03 52.561 25.717 0 47.278-8.486 63.038-23.033l-30.913-23.986c-8.486 5.715-19.31 9.179-32.125 9.179-24.765 0-45.806-16.712-53.34-39.226z" fill="#34a853" /><path clip-path="none" mask="none" d="M-1174.365-712.61c-6.494 12.815-10.217 27.276-10.217 42.689s3.723 29.874 10.217 42.689c0 .086 31.693-24.592 31.693-24.592-1.905-5.715-3.031-11.776-3.031-18.098s1.126-12.383 3.031-18.098z" fill="#fbbc05" /><path d="M-1089.333-727.244c14.028 0 26.497 4.849 36.455 14.201l27.276-27.276c-16.539-15.413-38.013-24.852-63.731-24.852-37.234 0-69.359 21.388-85.032 52.561l31.692 24.592c7.533-22.514 28.575-39.226 53.34-39.226z" fill="#ea4335" clip-path="none" mask="none" /></g></svg></a>&nbsp;&nbsp;<a class="bp3-button facebook compact" rel="nofollow" href="/authorize/facebook" role="tooltip" data-tip-pos="top" aria-label="Facebook로로그인"><svg width="20" height="20" viewBox="0 0 534 534" xmlns="http://www.w3.org/2000/svg" style="fill-rule:evenodd;clip-rule:evenodd;stroke-linejoin:round;stroke-miterlimit:2;"><g transform="matrix(1,0,0,1,-333.333,-133.333)"><path d="M866.667,400C866.667,252.724 747.276,133.333 600,133.333C452.724,133.333 333.333,252.724 333.333,400C333.333,533.101 430.849,643.422 558.333,663.427L558.333,477.083L490.625,477.083L490.625,400L558.333,400L558.333,341.25C558.333,274.417 598.145,237.5 659.057,237.5C688.233
.233ZM1028.32,1247.07L920.736,1247.07L920.736,753.092L1028.32,753.092C1186.36,753.092 1291.34,843.262 1291.34,998.698L1291.34,1001.47C1291.34,1158.2 1186.36,1247.07 1028.32,1247.07Z" style="fill:rgb(46,159,255);fill-rule:nonzero;" /></g></g></svg></a>&nbsp;&nbsp;<a class="bp3-button discord compact" rel="nofollow" href="/authorize/discord" role="tooltip" data-tip-pos="top" aria-label="Discord로로그인"><svg width="20" height="20" viewBox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg"><circle cx="512" cy="512" r="512" style="fill:#5865f2" /><path d="M689.43 349a422.21 422.21 0 0 0-104.22-32.32 1.58 1.58 0 0 0-1.68.79 294.11 294.11 0 0 0-13 26.66 389.78 389.78 0 0 0-117.05 0 269.75 269.75 0 0 0-13.18-26.66 1.64 1.64 0 0 0-1.68-.79A421 421 0 0 0 334.44 349a1.49 1.49 0 0 0-.69.59c-66.37 99.17-84.55 195.9-75.63 291.41a1.76 1.76 0 0 0 .67 1.2 424.58 424.58 0 0 0 127.85 64.63 1.66 1.66 0 0 0 1.8-.59 303.45 303.45 0 0 0 26.15-42.54 1.62 1.62 0 0 0-.89-2.25 279.6 279.6 0 0 1-39.94-19 1.64 1.64 0 0 1-.16-2.72c2.68-2 5.37-4.1 7.93-6.22a1.58 1.58 0 0 1 1.65-.22c83.79 38.26 174.51 38.26 257.31 0a1.58 1.58 0 0 1 1.68.2c2.56 2.11 5.25 4.23 8 6.24a1.64 1.64 0 0 1-.14 2.72 262.37 262.37 0 0 1-40 19 1.63 1.63 0 0 0-.87 2.28 340.72 340.72 0 0 0 26.13 42.52 1.62 1.62 0 0 0 1.8.61 423.17 423.17 0 0 0 128-64.63 1.64 1.64 0 0 0 .67-1.18c10.68-110.44-17.88-206.38-75.7-291.42a1.3 1.3 0 0 0-.63-.63zM427.09 582.85c-25.23 0-46-23.16-46-51.6s20.38-51.6 46-51.6c25.83 0 46.42 23.36 46 51.6.02 28.44-20.37 51.6-46 51.6zm170.13 0c-25.23 0-46-23.16-46-51.6s20.38-51.6 46-51.6c25.83 0 46.42 23.36 46 51.6.01 28.44-20.17 51.6-46 51.6z" style="fill:#fff" /></svg></a></div></form></div></div>
<div id="sign-up-form" class="hide"><div class="bp3-dialog-header"><h4 class="bp3-heading">가입하기</h4><button type="button" class="bp3-button bp3-minimal bp3-dialog-close-button btn-cancel"><span icon="small-cross" class="bp3-icon bp3-icon-small-cross"><svg viewBox="0 0 24 24" width="20" height="20"><line x1="18" y1="6" x2="6" y2="18"></line><line x1="6" y1="6" x2="18" y2="18"></line></svg></span></button></div><div class="bp3-dialog-body"><form method="post" action="/signUp" data-next="/teams" class="ajax-form"><div class="bp3-form-group bp3-inline"><input class="bp3-input bp3-fill" type="text" name="email" placeholder="이메일"></div><div class="bp3-form-group bp3-inline"><input class="bp3-input bp3-fill" type="text" name="name" placeholder="이름"></div><div class="bp3-form-group bp3-inline"><input class="bp3-input bp3-fill" type="password" name="password" id="password" placeholder="암호"></div><div class="bp3-form-group bp3-inline"><input class="bp3-input bp3-fill" type="password" name="confirmPassword" placeholder="비밀번호확인"></div><div class="bp3-form-group bp3-inline spacing"><div class="bp3-full-width text-right"><button type="submit" name="submit" class="bp3-button">제출</button></div></div></form></div></div>
<div id="forgot-form" class="hide"><div class="bp3-dialog-header"><h4 class="bp3-heading">비밀번호를잊으셨나요</h4><button type="button" class="bp3-button bp3-minimal bp3-dialog-close-button btn-cancel"><span icon="small-cross" class="bp3-icon bp3-icon-small-cross"><svg viewBox="0 0 24 24" width="20" height="20"><line x1="18" y1="6" x2="6" y2="18"></line><line x1="6" y1="6" x2="18" y2="18"></line></svg></span></button></div><div class="bp3-dialog-body"><form method="post" action="/forgot" class="ajax-form"><div class="bp3-form-group bp3-inline">이메일을제공해주세요.추가지침이포함된이메일을보내드리겠습니다.</div><div class="bp3-form-group bp3-inline"><input class="bp3-input bp3-fill" type="text" name="email" placeholder="이메일"></div><div class="bp3-form-group bp3-inline"><div class="bp3-full-width text-right"><button type="submit" name="submit" class="bp3-button">제출</button></div></div></form></div></div>
<script src="https://static.sofifa.net/js/desktop.min.js?20"></script>
<script defer src="https://static.sofifa.net/js/socket.min.js?2"></script>
<script defer src="https://static.sofifa.net/js/uploader.min.js?2"></script>
<script defer src="https://static.sofifa.net/js/comment.min.js?29"></script>
<script async src="https://cdn.intergient.com/1024268/72628/ramp_config.js"></script>
<script async src="https://static.sofifa.net/js/ramp.min.js?2"></script>
<script async src="https://cdn.intergient.com/ramp_core.js"></script>
<script async src="https://www.googletagmanager.com/gtag/js?id=G-X81LWDNFGR"></script>
<script>window.dataLayer = window.dataLayer || [];function gtag(){dataLayer.push(arguments);}gtag('js', new Date());gtag('config', 'G-X81LWDNFGR');</script>
</body>
</html>'''

# %%
# BeautifulSoup을 사용하여 HTML 파싱
soup1 = BeautifulSoup(html1, 'html.parser')

# 팀 이름 추출
team_name1 = soup1.find_all('div', class_='ellipsis')

# 레이팅 값 추출 (여기서는 'p-85'로 클래스가 지정되어 있는 span 태그를 찾음)
rating1 = soup1.find_all('span', class_='bp3-tag')

# %%
# BeautifulSoup을 사용하여 HTML 파싱
soup2 = BeautifulSoup(html2, 'html.parser')

# 팀 이름 추출
team_name2 = soup2.find_all('div', class_='ellipsis')

# 레이팅 값 추출 (여기서는 'p-85'로 클래스가 지정되어 있는 span 태그를 찾음)
rating2 = soup2.find_all('span', class_='bp3-tag')

# %%
# BeautifulSoup을 사용하여 HTML 파싱
soup3 = BeautifulSoup(html3, 'html.parser')

# 팀 이름 추출
team_name3 = soup3.find_all('div', class_='ellipsis')

# 레이팅 값 추출 (여기서는 'p-85'로 클래스가 지정되어 있는 span 태그를 찾음)
rating3 = soup3.find_all('span', class_='bp3-tag')

# %%
team_list = []
for i in range(0,120,2):
    team_list.append(team_name1[i].text)
for i in range(0,120,2):
    team_list.append(team_name2[i].text)
for i in range(0,120,2):
    team_list.append(team_name3[i].text)

# %%
overall_list = []
fw_list = []
mid_list = []
df_list = []
for i in range(0,60):
    overall_list.append(rating1[4*i].text)
    fw_list.append(rating1[4*i+1].text)
    mid_list.append(rating1[4*i+2].text)
    df_list.append(rating1[4*i+3].text)
for i in range(0,60):
    overall_list.append(rating2[4*i].text)
    fw_list.append(rating2[4*i+1].text)
    mid_list.append(rating2[4*i+2].text)
    df_list.append(rating2[4*i+3].text)
for i in range(0,60):
    overall_list.append(rating3[4*i].text)
    fw_list.append(rating3[4*i+1].text)
    mid_list.append(rating3[4*i+2].text)
    df_list.append(rating3[4*i+3].text)

# %%
final_list = list(zip(team_list,overall_list,fw_list,mid_list,df_list))

# %%
len(final_list)
# Out:
# 180

# %%
teamDF = pd.DataFrame(final_list, columns=['team','TOTAL_MEAN','FW','MID','DF'])

# %%
teamDF.to_csv('footballclub_2023_top180.csv', index=False)
